# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
import seaborn as sns

import itertools
import re
import string
import pickle
import os

import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, f1_score, make_scorer
from sklearn.model_selection import KFold

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.corpus import stopwords, wordnet
from wordcloud import WordCloud
from copy import deepcopy

from IPython.display import (
    Markdown as md,
    Latex,
    HTML,
)

from tqdm.auto import tqdm
import json

# set plot style
sns.set()

from google.colab import drive

drive.mount('/content/drive')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/nlp data/Data/news_feed_all_docs_dropped.csv")

# %%
df.head()
# Out:
#               categories                                                url  \
# 0    ['Manchester City']  https://www.mirror.co.uk/sport/football/news/p...
# 1  ['Manchester United']  https://metro.co.uk/2023/09/25/gran-74-left-sh...
# 2  ['Manchester United']  https://www.manutd.com/en/news/detail/man-utd-...
# 3  ['Manchester United']  https://www.teamtalk.com/manchester-united/ten...
# 4    ['Manchester City']  https://www.manchestercity.news/soon-pep-guard...
#
#                                                title  \
# 0  10 most expensive Premier League keepers with ...
# 1  Gran in crash with Marcus Rashford had no idea...
# 2                     Match preview: United v Palace
# 3  Man Utd want €50m LaLiga star in huge January ...
# 4  Pep Guardiola delivers new injury update on Ma...
#
#                                              content               author  \
# 0  The top 10 most valuable Premier League goalke...   ['Matthew Cooper']
# 1  The England striker was involved in the crash ...     ['Liam Coleman']
# 2  Skip to Main NavigationSkip to contentHow to f...     ['Matthew Holt']
# 3  Manchester United are reportedly weighing up a...  ['James Marshment']
# 4  Pep Guardiola gave an injury update on Manches...      ['Tom Procter']
#
#                         date spider_type
# 0  2023-09-25 14:31:18+00:00     newsnow
# 1  2023-09-25 15:58:13+00:00     newsnow
# 2  2023-09-25 16:12:33+00:00     newsnow
# 3  2023-09-25 15:51:58+00:00     newsnow
# 4  2023-09-25 15:34:43+00:00     newsnow

# %%
# !pip install spacy tqdm
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 67.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# %%
top_five_content = df['content'].head(5)

# Process each entry with spaCy
for i, content in enumerate(top_five_content):
    doc = nlp(content)
    print(f"Text {i + 1}:")
    print(f"Entities: {[ent.text for ent in doc.ents]}")
    print(f"TOKENS: {[token.text for token in doc]}")
    print(f"POS Tags: {[token.pos_ for token in doc]}")
    print(f"Dependency Labels: {[token.dep_ for token in doc]}")
    print("\n")
# Out:
# Text 1:
# Entities: ['10', 'Premier League', 'Liverpool', 'Alisson', "Manchester City's", 'Liverpool', 'Ederson and AlissonLiverpool', 'Alisson', "Manchester City's", 'Ederson', 'two', 'The Football Observatory', 'Alisson', 'Ederson', 'nine', '10', 'two', 'Mirror Football', '10', 'Arijanet Muric - Burnley', 'Burnley', 'first', 'James Trafford', 'Aijanet Muric', '24-year-old', 'last year', '2026', '9', 'Emiliano Martinez - Aston', '20m/£17.3', 'World Cup', 'Argentina', 'last year', 'Emiliano Martinez', 'Arsenal', '2020', 'Bernd Leno', 'Aston Villa', 'later that same year', 'Martinez', '31-year-old', 'three-year', 'last January', 'David Raya - Arsenal', 'David Raya', 'the summer', 'Getty Images', 'Arsenal', 'Brentford', 'next summer', 'David Raya', 'Aaron Ramsdale', 'Emirates', 'Spanish', 'Raya', 'two-year', 'Brentford', '7', 'Jordan Pickford - Everton', '20m/£17.3', 'England', 'first', 'Gareth Southgate', 'Jordan Pickford', 'Everton', '2017', 'Sunderland', '29-year-old', 'the years', 'one', 'Everton', 'the end of 2027 earlier this year', '6', 'Vlachodimos - Nottingham Forest', 'Odysseas Vlachodimos', 'Nottingham Forest', 'Benfica', 'the summer', 'four-year', '29-year-old', 'Forest', 'Matt Turner', 'first', 'Arsenal', 'Robert Sanchez - Chelsea', 'Robert Sanchez', 'Chelsea', 'No 1', 'Robin Jones - AFC Bournemouth', 'Getty Images', 'Brighton', 'Jason Steele', 'last season', 'Robert Sanchez', '20', 'Chelsea', 'this summer', 'Edouard Mendy', 'Kepa Arrizabalaga', '25-year-old', 'seven-year', 'Blues', '4.', 'Andre Onana - Man Utd', '50m/£43.4', 'Manchester United', '43.8', 'Andre Onana', 'Inter Milan', "David de Gea's", 'Cameroon', 'Inter', 'the Champions League', 'last season', 'Old Trafford', '3', 'Alisson - Liverpool', '60m/£52.1', 'Alisson', 'Ederson ( Image:', 'Roma', 'Liverpool', '2018', 'Alisson', 'Reds', 'Jurgen Klopp', '30-year-old', '2027', 'Liverpool', 'the Premier League', 'Champions League', 'FA Cup', '2', 'Ederson - Man City', '2017', 'Benfica', 'Claudio Bravo', 'Ederson', "Manchester City's", 'Ederson', 'five', 'Premier League', 'two', 'four', 'League Cups', '1', 'Aaron Ramsdale - Arsenal', 'number one', "Mikel Arteta's", 'first', 'Raya', 'Aaron Ramsdale', 'almost £70', 'The Football Observatory', 'two seasons', 'Gunners', 'Raya', 'The Football Observatory', 'WhatsApp', 'daily', 'Mirror Football', 'Privacy Notice', 'Learn more Watch the Premier League', 'Champions League', 'Europa League', 'TNT Sports', 'the Premier League', 'Champions League', 'Europa League', 'Serie A', 'UFC', 'WWE', 'MLB', 'one', 'every month', 'TNT Sports', 'BT', 'Sky', 'Virgin Media', '29.99', 'TNT Sports']
# TOKENS: ['The', 'top', '10', 'most', 'valuable', 'Premier', 'League', 'goalkeepers', 'have', 'been', 'revealed', ',', 'with', 'Liverpool', "'s", 'Alisson', 'and', 'Manchester', 'City', "'s", 'Ederson', 'missing', 'out', 'on', 'the', 'number', 'one', 'spotManchester', 'City', 'and', 'Liverpool', 'goalkeepers', 'Ederson', 'and', 'AlissonLiverpool', 'star', 'Alisson', 'and', 'Manchester', 'City', "'s", 'Ederson', 'are', 'widely', 'viewed', 'as', 'two', 'of', 'the', 'best', 'goalkeepers', 'in', 'the', 'world', '-', 'but', 'where', 'do', 'they', 'rank', 'among', 'the', 'Premier', 'League', "'s", 'most', 'valuable', 'shot', '-', 'stoppers', '?', 'Well', ',', 'The', 'Football', 'Observatory', 'has', 'all', 'the', 'answers', 'and', 'you', 'might', 'be', 'surprised', 'to', 'learn', 'that', 'neither', 'Alisson', 'or', 'Ederson', 'take', 'the', 'number', 'one', 'spot', '.', 'When', 'ranking', 'players', "'", 'value', ',', 'they', 'take', 'a', 'wide', 'range', 'of', 'factors', 'into', 'account', ':', 'age', ',', 'contract', 'length', ',', 'form', 'and', 'so', 'on', '.', 'A', 'total', 'of', 'nine', 'different', 'clubs', 'are', 'represented', 'in', 'the', 'top', '10', ',', 'with', 'Arsenal', 'the', 'only', 'club', 'having', 'two', 'players', 'on', 'the', 'list', '.', 'Here', ',', 'Mirror', 'Football', 'gives', 'you', 'the', 'rundown', 'on', 'the', 'league', "'s", 'most', 'valuable', 'goalkeepers', '...', '10', '.', 'Arijanet', 'Muric', '-', 'Burnley', '(', '€', '20million/£17.3', 'm', ')', 'After', 'losing', 'his', 'spot', 'as', 'Burnley', "'s", 'first', '-', 'choice', 'goalkeeper', 'to', 'new', 'signing', 'James', 'Trafford', ',', 'Aijanet', 'Muric', 'is', 'probably', 'the', 'most', 'surprising', 'name', 'on', 'the', 'list', '.', 'However', ',', 'the', '24', '-', 'year', '-', 'old', 'was', 'excellent', 'in', 'the', 'Championship', 'last', 'year', ',', 'while', 'his', 'age', 'and', 'the', 'fact', 'he', 'is', 'under', 'contract', 'until', '2026', 'help', 'boost', 'his', 'value', '.', '9', '.', 'Emiliano', 'Martinez', '-', 'Aston', 'Villa', '(', '€', '20m/£17.3', 'm', ')', 'A', 'World', 'Cup', 'winner', 'with', 'Argentina', 'last', 'year', ',', 'Emiliano', 'Martinez', 'has', 'developed', 'into', 'one', 'of', 'the', 'best', 'goalkeepers', 'in', 'the', 'world', 'after', 'enjoying', 'a', 'breakthrough', 'at', 'Arsenal', 'in', '2020', 'when', 'Bernd', 'Leno', 'was', 'sidelined', 'with', 'an', 'injury', '.', 'After', 'joining', 'Aston', 'Villa', 'later', 'that', 'same', 'year', ',', 'Martinez', 'has', 'continued', 'to', 'impress', 'and', 'the', '31', '-', 'year', '-', 'old', 'signed', 'a', 'three', '-', 'year', 'contract', 'extension', 'last', 'January', '.', '8', '.', 'David', 'Raya', '-', 'Arsenal', '(', '€', '20m/£17.3', 'm', ')', 'David', 'Raya', 'joined', 'Arsenal', 'over', 'the', 'summer', '(', 'Image', ':', 'Arsenal', 'FC', 'via', 'Getty', 'Images', ')', 'Currently', 'on', 'loan', 'at', 'Arsenal', 'from', 'Brentford', 'with', 'an', 'option', 'for', 'the', 'deal', 'to', 'be', 'made', 'permanent', 'next', 'summer', ',', 'David', 'Raya', 'is', 'now', 'competing', 'with', 'Aaron', 'Ramsdale', 'for', 'the', 'No', '1', 'spot', 'at', 'the', 'Emirates', '.', 'Spanish', 'international', 'Raya', 'did', 'sign', 'a', 'two', '-', 'year', 'contract', 'extension', 'with', 'Brentford', 'before', 'joining', 'the', 'Gunners', 'in', 'case', 'they', 'do', 'not', 'take', 'up', 'the', 'option', 'to', 'buy', '.', '7', '.', 'Jordan', 'Pickford', '-', 'Everton', '(', '€', '20m/£17.3', 'm', ')', 'England', "'s", 'first', '-', 'choice', 'goalkeeper', 'under', 'Gareth', 'Southgate', ',', 'Jordan', 'Pickford', 'made', 'the', 'move', 'to', 'Everton', 'in', '2017', 'after', 'impressing', 'as', 'Sunderland', 'were', 'relegated', 'to', 'the', 'Championship', '.', 'The', '29', '-', 'year', '-', 'old', 'has', 'come', 'in', 'for', 'criticism', 'over', 'the', 'years', ',', 'but', 'he', 'remains', 'one', 'of', 'Everton', "'s", 'key', 'players', 'after', 'committing', 'his', 'fu ...
# POS Tags: ['DET', 'ADJ', 'NUM', 'ADV', 'ADJ', 'PROPN', 'PROPN', 'NOUN', 'AUX', 'AUX', 'VERB', 'PUNCT', 'ADP', 'PROPN', 'PART', 'PROPN', 'CCONJ', 'PROPN', 'PROPN', 'PART', 'PROPN', 'VERB', 'ADP', 'ADP', 'DET', 'NOUN', 'NUM', 'NOUN', 'PROPN', 'CCONJ', 'PROPN', 'NOUN', 'PROPN', 'CCONJ', 'PROPN', 'PROPN', 'PROPN', 'CCONJ', 'PROPN', 'PROPN', 'PART', 'PROPN', 'AUX', 'ADV', 'VERB', 'ADP', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT', 'CCONJ', 'SCONJ', 'AUX', 'PRON', 'VERB', 'ADP', 'DET', 'PROPN', 'PROPN', 'PART', 'ADV', 'ADJ', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'INTJ', 'PUNCT', 'DET', 'PROPN', 'PROPN', 'VERB', 'DET', 'DET', 'NOUN', 'CCONJ', 'PRON', 'AUX', 'AUX', 'ADJ', 'PART', 'VERB', 'SCONJ', 'CCONJ', 'PROPN', 'CCONJ', 'PROPN', 'VERB', 'DET', 'NOUN', 'NUM', 'NOUN', 'PUNCT', 'SCONJ', 'VERB', 'NOUN', 'PART', 'NOUN', 'PUNCT', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'CCONJ', 'ADV', 'ADV', 'PUNCT', 'DET', 'NOUN', 'ADP', 'NUM', 'ADJ', 'NOUN', 'AUX', 'VERB', 'ADP', 'DET', 'ADJ', 'NUM', 'PUNCT', 'ADP', 'PROPN', 'DET', 'ADJ', 'NOUN', 'VERB', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT', 'ADV', 'PUNCT', 'PROPN', 'PROPN', 'VERB', 'PRON', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PART', 'ADV', 'ADJ', 'NOUN', 'PUNCT', 'NUM', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PUNCT', 'SYM', 'PROPN', 'PROPN', 'PUNCT', 'ADP', 'VERB', 'PRON', 'NOUN', 'ADP', 'PROPN', 'PART', 'ADJ', 'PUNCT', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'AUX', 'ADV', 'DET', 'ADV', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT', 'ADV', 'PUNCT', 'DET', 'NUM', 'PUNCT', 'NOUN', 'PUNCT', 'ADJ', 'AUX', 'ADJ', 'ADP', 'DET', 'PROPN', 'ADJ', 'NOUN', 'PUNCT', 'SCONJ', 'PRON', 'NOUN', 'CCONJ', 'DET', 'NOUN', 'PRON', 'AUX', 'ADP', 'NOUN', 'SCONJ', 'NUM', 'NOUN', 'VERB', 'PRON', 'NOUN', 'PUNCT', 'X', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'SYM', 'NUM', 'NUM', 'PUNCT', 'DET', 'PROPN', 'PROPN', 'NOUN', 'ADP', 'PROPN', 'ADJ', 'NOUN', 'PUNCT', 'PROPN', 'PROPN', 'AUX', 'VERB', 'ADP', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'PROPN', 'ADP', 'NUM', 'SCONJ', 'PROPN', 'PROPN', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', 'PUNCT', 'ADP', 'VERB', 'PROPN', 'PROPN', 'ADV', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'PROPN', 'AUX', 'VERB', 'PART', 'VERB', 'CCONJ', 'DET', 'NUM', 'PUNCT', 'NOUN', 'PUNCT', 'ADJ', 'VERB', 'DET', 'NUM', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'PROPN', 'PUNCT', 'NUM', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PUNCT', 'SYM', 'NUM', 'NUM', 'PUNCT', 'PROPN', 'PROPN', 'VERB', 'PROPN', 'ADP', 'DET', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'PROPN', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'PUNCT', 'ADV', 'ADP', 'NOUN', 'ADP', 'PROPN', 'ADP', 'PROPN', 'ADP', 'DET', 'NOUN', 'SCONJ', 'DET', 'NOUN', 'PART', 'AUX', 'VERB', 'ADJ', 'ADJ', 'NOUN', 'PUNCT', 'PROPN', 'PROPN', 'AUX', 'ADV', 'VERB', 'ADP', 'PROPN', 'PROPN', 'ADP', 'DET', 'DET', 'NUM', 'NOUN', 'ADP', 'DET', 'PROPN', 'PUNCT', 'ADJ', 'ADJ', 'PROPN', 'AUX', 'VERB', 'DET', 'NUM', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'ADP', 'VERB', 'DET', 'PROPN', 'ADP', 'NOUN', 'PRON', 'AUX', 'PART', 'VERB', 'ADP', 'DET', 'NOUN', 'PART', 'VERB', 'PUNCT', 'X', 'X', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PUNCT', 'SYM', 'NUM', 'NOUN', 'PUNCT', 'PROPN', 'PART', 'ADJ', 'PUNCT', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'VERB', 'DET', 'NOUN', 'ADP', 'PROPN', 'ADP', 'NUM', 'ADP', 'VERB', 'SCONJ', 'PROPN', 'AUX', 'VERB', 'ADP', 'DET', 'PROPN', 'PUNCT', 'DET', 'NUM', 'PUNCT', 'NOUN', 'PUNCT', 'ADJ', 'AUX', 'VERB', 'ADP', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT', 'CCONJ', 'PRON', 'VERB', 'NUM', 'ADP', 'PROPN', 'PART', 'ADJ', 'NOUN', 'ADP', 'VERB', 'PRON', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'ADV', 'DET', 'NOUN', 'PUNCT', 'X', 'X', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'SYM', 'NUM', 'NOUN ...
# Dependency Labels: ['det', 'amod', 'nummod', 'advmod', 'amod', 'compound', 'compound', 'nsubjpass', 'aux', 'auxpass', 'ROOT', 'punct', 'prep', 'poss', 'case', 'nsubj', 'cc', 'compound', 'poss', 'case', 'conj', 'pcomp', 'prt', 'prep', 'det', 'nmod', 'nummod', 'nmod', 'nmod', 'cc', 'conj', 'pobj', 'nmod', 'cc', 'conj', 'conj', 'nsubjpass', 'cc', 'compound', 'poss', 'case', 'conj', 'auxpass', 'advmod', 'conj', 'prep', 'pobj', 'prep', 'det', 'amod', 'pobj', 'prep', 'det', 'pobj', 'punct', 'cc', 'advmod', 'aux', 'nsubj', 'conj', 'prep', 'det', 'compound', 'poss', 'case', 'advmod', 'amod', 'compound', 'punct', 'pobj', 'punct', 'intj', 'punct', 'det', 'compound', 'nsubj', 'ROOT', 'predet', 'det', 'dobj', 'cc', 'nsubj', 'aux', 'conj', 'acomp', 'aux', 'xcomp', 'mark', 'preconj', 'nsubj', 'cc', 'conj', 'ccomp', 'det', 'nmod', 'nummod', 'dobj', 'punct', 'advmod', 'amod', 'poss', 'case', 'advcl', 'punct', 'nsubj', 'ROOT', 'det', 'amod', 'dobj', 'prep', 'pobj', 'prep', 'pobj', 'punct', 'dobj', 'punct', 'compound', 'conj', 'punct', 'conj', 'cc', 'advmod', 'conj', 'punct', 'det', 'nsubjpass', 'prep', 'nummod', 'amod', 'pobj', 'auxpass', 'ROOT', 'prep', 'det', 'amod', 'pobj', 'punct', 'prep', 'pobj', 'det', 'amod', 'appos', 'acl', 'nummod', 'dobj', 'prep', 'det', 'pobj', 'punct', 'advmod', 'punct', 'compound', 'nsubj', 'ROOT', 'dative', 'det', 'dobj', 'prep', 'det', 'poss', 'case', 'advmod', 'amod', 'pobj', 'punct', 'appos', 'punct', 'compound', 'compound', 'punct', 'ROOT', 'punct', 'nmod', 'appos', 'appos', 'punct', 'prep', 'pcomp', 'poss', 'dobj', 'prep', 'poss', 'case', 'amod', 'punct', 'compound', 'pobj', 'prep', 'amod', 'pobj', 'compound', 'npadvmod', 'punct', 'compound', 'nsubj', 'ROOT', 'advmod', 'det', 'advmod', 'amod', 'attr', 'prep', 'det', 'pobj', 'punct', 'advmod', 'punct', 'det', 'nummod', 'punct', 'npadvmod', 'punct', 'nsubj', 'ROOT', 'acomp', 'prep', 'det', 'pobj', 'amod', 'npadvmod', 'punct', 'mark', 'poss', 'nsubj', 'cc', 'det', 'conj', 'nsubj', 'advcl', 'prep', 'pobj', 'mark', 'pobj', 'nsubj', 'advcl', 'poss', 'dobj', 'punct', 'ROOT', 'punct', 'compound', 'compound', 'punct', 'compound', 'ROOT', 'punct', 'nmod', 'appos', 'appos', 'punct', 'det', 'compound', 'compound', 'nsubj', 'prep', 'pobj', 'amod', 'npadvmod', 'punct', 'compound', 'nsubj', 'aux', 'ROOT', 'prep', 'pobj', 'prep', 'det', 'amod', 'pobj', 'prep', 'det', 'pobj', 'prep', 'pcomp', 'det', 'dobj', 'prep', 'pobj', 'prep', 'pobj', 'advmod', 'compound', 'nsubjpass', 'auxpass', 'advcl', 'prep', 'det', 'pobj', 'punct', 'prep', 'pcomp', 'compound', 'dobj', 'advmod', 'det', 'amod', 'npadvmod', 'punct', 'nsubj', 'aux', 'ROOT', 'aux', 'xcomp', 'cc', 'det', 'nummod', 'punct', 'npadvmod', 'punct', 'nsubj', 'conj', 'det', 'nummod', 'punct', 'compound', 'compound', 'dobj', 'amod', 'npadvmod', 'punct', 'ROOT', 'punct', 'compound', 'compound', 'punct', 'ROOT', 'punct', 'nmod', 'appos', 'appos', 'punct', 'compound', 'nsubj', 'ROOT', 'dobj', 'prep', 'det', 'pobj', 'punct', 'parataxis', 'punct', 'compound', 'appos', 'prep', 'compound', 'pobj', 'punct', 'advmod', 'prep', 'pobj', 'prep', 'pobj', 'prep', 'pobj', 'prep', 'det', 'pobj', 'mark', 'det', 'nsubjpass', 'aux', 'auxpass', 'acl', 'amod', 'amod', 'npadvmod', 'punct', 'compound', 'nsubj', 'aux', 'advmod', 'ROOT', 'prep', 'compound', 'pobj', 'prep', 'det', 'det', 'nummod', 'pobj', 'prep', 'det', 'pobj', 'punct', 'amod', 'amod', 'nsubj', 'aux', 'ROOT', 'det', 'nummod', 'punct', 'compound', 'compound', 'dobj', 'prep', 'pobj', 'prep', 'pcomp', 'det', 'dobj', 'prep', 'pobj', 'nsubj', 'aux', 'neg', 'ccomp', 'prt', 'det', 'dobj', 'aux', 'acl', 'punct', 'meta', 'compound', 'compound', 'compound', 'punct', 'ROOT', 'punct', 'nmod', 'appos', 'appos', 'punct', 'poss', 'case', 'amod', 'punct', 'compound', 'nsubj', 'prep', 'compound', 'pobj', 'punct', 'compound', 'nsubj', 'ROOT', 'det', 'dobj', 'prep', 'pobj', 'prep', 'pobj', 'prep', 'pcomp', 'mark', 'nsubjpass', 'auxpass', 'advcl', 'prep', 'det', 'pobj', 'punct', 'det', 'nummod', 'punct', 'npa ...
#
#
# Text 2:
# Entities: ['England', 'yesterday', 'Marcus Rashford', '74-year-old', 'England', '25-year-old', 'Manchester United', '700,000', 'Rolls Royce', 'Sun', 'United', 'around midnight', 'Saturday', 'Rashford', 'Rolls-Royce', 'JavaScript', 'HTML5', 'United', 'Carrington', '1', 'Burnley', 'Sun', 'Maintenance', 'Peter Laycock', '36', 'Peter', 'United', 'Rashford', '40mph', 'Carrington Spur', 'United', 'just before midnight', 'Marcus Rashford', 'Bruno Fernandes', 'United', 'Rashford', 'five', '15 miles', 'three', 'Rashford', 'United', '3', 'reCAPTCHA', 'the Google Privacy Policy and Terms of Service']
# TOKENS: ['The', 'England', 'striker', 'was', 'involved', 'in', 'the', 'crash', 'with', 'the', 'grandmother', 'yesterday', '(', 'Picture', ':', 'Getty)A', 'grandmother', 'was', 'on', 'her', 'way', 'home', 'from', 'babysitting', 'when', 'she', 'was', 'involved', 'in', 'a', 'car', 'crash', 'with', 'Marcus', 'Rashford', ',', 'it', 'has', 'been', 'revealed', '.', 'The', '74', '-', 'year', '-', 'old', 'had', 'been', 'looking', 'after', 'her', 'granddaughter', 'when', 'she', 'escaped', 'without', 'injury', 'in', 'the', 'incident', 'with', 'the', 'England', 'striker', '.', 'The', '25', '-', 'year', '-', 'old', 'Manchester', 'United', 'star', '’s', '£', '700,000', 'Rolls', 'Royce', 'was', 'wrecked', 'in', 'the', 'collision', '.', 'According', 'to', 'The', 'Sun', ',', 'the', 'woman', 'was', '‘', 'very', 'shaken', '’', 'but', 'unhurt', 'following', 'the', 'incident', 'near', 'United', '’s', 'training', 'complex', 'at', 'around', 'midnight', 'on', 'Saturday', '.', 'Rashford', '’s', 'Rolls', '-', 'Royce', 'knocked', 'down', 'a', 'traffic', 'light', 'camera', 'post', 'in', 'the', 'crash', '.', 'To', 'view', 'this', 'video', 'please', 'enable', 'JavaScript', ',', 'and', 'consider', 'upgrading', 'to', 'a', 'web', 'browser', 'that', 'supports', 'HTML5', 'video', 'He', 'had', 'just', 'left', 'United', '’s', 'training', 'ground', 'in', 'Carrington', 'on', 'his', 'way', 'home', 'from', 'his', 'side', '’s', '1', '-', '0', 'Premier', 'League', 'win', 'at', 'Burnley', '.', 'A', 'source', 'told', 'The', 'Sun', ':', '‘', 'Both', 'drivers', 'were', 'badly', 'shaken', '.', '‘', 'Marcus', 'immediately', 'checked', 'to', 'see', 'if', 'the', 'woman', 'was', 'okay', 'and', 'swapped', 'details', '.', '’', 'Maintenance', 'engineer', 'Peter', 'Laycock', ',', '36', ',', 'caught', 'the', 'aftermath', 'of', 'the', 'accident', 'on', 'his', 'mobile', 'phone', 'after', 'arriving', 'at', 'the', 'scene', 'at', 'around', '12.20am', '.', 'Peter', 'said', ':', '‘', 'There', 'were', 'loads', 'of', 'police', 'blocking', 'the', 'road', 'asking', 'cars', 'to', 'turn', 'around', 'because', 'there', 'was', 'debris', 'all', 'over', 'the', 'road', '.', '‘', 'I', 'could', 'see', 'guys', 'in', 'United', 'clothes', 'who', 'must', 'have', 'come', 'from', 'the', 'training', 'ground', '.', 'There', 'were', 'a', 'lot', 'of', 'bystanders', 'saying', ',', '‘', 'It', '’s', '¬Marcus', 'Rashford', '’s', 'car', '’', '.', '’', 'Footage', 'showed', 'his', 'car', 'with', 'pieces', 'of', 'the', 'rear', 'bumper', 'ripped', 'off', 'and', 'strewn', 'on', 'the', 'side', 'of', 'the', 'road', 'as', 'hazard', 'lights', 'flashed', '.', 'No', 'arrests', 'were', 'made', 'and', 'police', 'decided', 'not', 'to', 'call', 'an', 'ambulance', 'as', 'the', 'female', 'driver', 'said', 'she', 'did', 'not', 'want', 'to', 'go', 'to', 'hospital', '.', 'Footage', 'of', 'the', 'crash', 'was', 'posted', 'online', '(', 'Picture', ':', 'Twitter)The', 'accident', 'happened', 'in', 'a', '40', 'mph', 'zone', 'on', 'Carrington', 'Spur', 'near', 'United', '’s', 'Aon', 'training', 'complex', '—', 'where', 'players', 'had', 'returned', 'by', 'coach', 'just', 'before', 'midnight', '.', 'Another', 'source', 'told', 'The', 'Sun', ':', '‘', 'The', 'woman', 'was', 'on', 'her', 'way', 'home', 'from', 'baby¬sitting', 'her', 'grand', '-', 'daughter', '.', 'She', '’s', 'a', 'cautious', ',', 'careful', 'driver', 'and', 'even', 'more', 'so', 'when', 'it', '’s', 'raining', '—', 'which', 'it', 'was', '.', '‘', 'The', 'impact', 'caused', 'the', 'airbags', 'to', 'go', 'off', '.', 'She', 'was', 'very', ',', 'very', 'shaken', 'and', 'confused', '.', 'She', '’s', 'not', 'a', 'football', 'fan', 'and', 'did', 'n’t', 'have', 'any', 'idea', 'who', 'Marcus', 'Rashford', 'is', '.', '’', 'Club', 'captain', 'Bruno', 'Fernandes', 'soon', 'arrived', 'and', 'checked', 'on', 'both', 'his', 'team', '-', 'mate', 'and', 'the', 'pensioner', '.', 'United', '’s', 'club', 'doctor', 'checked', 'over', 'Rashford', 'and', 'offered', 'medical', 'aid', 'to', 'the', 'gra ...
# POS Tags: ['DET', 'PROPN', 'NOUN', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'PROPN', 'NOUN', 'AUX', 'ADP', 'PRON', 'NOUN', 'ADV', 'ADP', 'VERB', 'SCONJ', 'PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'PUNCT', 'PRON', 'AUX', 'AUX', 'VERB', 'PUNCT', 'DET', 'NUM', 'PUNCT', 'NOUN', 'PUNCT', 'ADJ', 'AUX', 'AUX', 'VERB', 'ADP', 'PRON', 'NOUN', 'SCONJ', 'PRON', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'PROPN', 'NOUN', 'PUNCT', 'DET', 'NUM', 'PUNCT', 'NOUN', 'PUNCT', 'ADJ', 'PROPN', 'PROPN', 'PROPN', 'PART', 'SYM', 'NUM', 'PROPN', 'PROPN', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', 'PUNCT', 'VERB', 'ADP', 'DET', 'PROPN', 'PUNCT', 'DET', 'NOUN', 'AUX', 'PUNCT', 'ADV', 'VERB', 'PUNCT', 'CCONJ', 'ADJ', 'VERB', 'DET', 'NOUN', 'ADP', 'PROPN', 'PART', 'NOUN', 'NOUN', 'ADP', 'ADP', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'PROPN', 'PART', 'PROPN', 'PUNCT', 'PROPN', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT', 'PART', 'VERB', 'DET', 'NOUN', 'INTJ', 'VERB', 'PROPN', 'PUNCT', 'CCONJ', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'PRON', 'VERB', 'PROPN', 'NOUN', 'PRON', 'AUX', 'ADV', 'VERB', 'PROPN', 'PART', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'ADP', 'PRON', 'NOUN', 'ADV', 'ADP', 'PRON', 'NOUN', 'PART', 'NUM', 'SYM', 'NUM', 'PROPN', 'PROPN', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'DET', 'NOUN', 'VERB', 'DET', 'PROPN', 'PUNCT', 'PUNCT', 'DET', 'NOUN', 'AUX', 'ADV', 'VERB', 'PUNCT', 'PUNCT', 'PROPN', 'ADV', 'VERB', 'PART', 'VERB', 'SCONJ', 'DET', 'NOUN', 'AUX', 'ADJ', 'CCONJ', 'VERB', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN', 'NOUN', 'PROPN', 'PROPN', 'PUNCT', 'NUM', 'PUNCT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'ADJ', 'NOUN', 'ADP', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'ADP', 'NUM', 'PUNCT', 'PROPN', 'VERB', 'PUNCT', 'PUNCT', 'PRON', 'VERB', 'NOUN', 'ADP', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'NOUN', 'PART', 'VERB', 'ADV', 'SCONJ', 'PRON', 'VERB', 'NOUN', 'ADV', 'ADP', 'DET', 'NOUN', 'PUNCT', 'PUNCT', 'PRON', 'AUX', 'VERB', 'NOUN', 'ADP', 'PROPN', 'NOUN', 'PRON', 'AUX', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'PUNCT', 'PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'PUNCT', 'PUNCT', 'PRON', 'VERB', 'PUNCT', 'PROPN', 'PART', 'NOUN', 'PUNCT', 'PUNCT', 'PUNCT', 'NOUN', 'VERB', 'PRON', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'CCONJ', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'SCONJ', 'NOUN', 'NOUN', 'VERB', 'PUNCT', 'DET', 'NOUN', 'AUX', 'VERB', 'CCONJ', 'NOUN', 'VERB', 'PART', 'PART', 'VERB', 'DET', 'NOUN', 'SCONJ', 'DET', 'ADJ', 'NOUN', 'VERB', 'PRON', 'AUX', 'PART', 'VERB', 'PART', 'VERB', 'ADP', 'NOUN', 'PUNCT', 'NOUN', 'ADP', 'DET', 'NOUN', 'AUX', 'VERB', 'ADJ', 'PUNCT', 'PROPN', 'PUNCT', 'VERB', 'NOUN', 'VERB', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'ADP', 'PROPN', 'PART', 'PROPN', 'NOUN', 'NOUN', 'PUNCT', 'SCONJ', 'NOUN', 'AUX', 'VERB', 'ADP', 'NOUN', 'ADV', 'ADP', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'VERB', 'DET', 'PROPN', 'PUNCT', 'PUNCT', 'DET', 'NOUN', 'AUX', 'ADP', 'PRON', 'NOUN', 'ADV', 'ADP', 'VERB', 'PRON', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'PRON', 'VERB', 'DET', 'ADJ', 'PUNCT', 'ADJ', 'NOUN', 'CCONJ', 'ADV', 'ADV', 'ADV', 'SCONJ', 'PRON', 'VERB', 'NOUN', 'PUNCT', 'PRON', 'PRON', 'AUX', 'PUNCT', 'PUNCT', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'PART', 'VERB', 'ADP', 'PUNCT', 'PRON', 'AUX', 'ADV', 'PUNCT', 'ADV', 'VERB', 'CCONJ', 'VERB', 'PUNCT', 'PRON', 'VERB', 'PART', 'DET', 'NOUN', 'NOUN', 'CCONJ', 'AUX', 'PART', 'VERB', 'DET', 'NOUN', 'PRON', 'PROPN', 'PROPN', 'AUX', 'PUNCT', 'PUNCT', 'NOUN', 'NOUN', 'PROPN', 'PROPN', 'ADV', 'VERB', 'CCONJ', 'VERB', 'ADP', 'CCONJ', 'PRON', 'NOUN', 'PUNCT', 'NOUN', 'CCONJ', 'DET', 'NOUN', 'PUNCT', 'PROPN', 'PART', 'NOUN', 'NOUN', 'VERB', 'ADP', 'PROPN', 'CCONJ', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'PUNCT', 'NOUN', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'PART', 'VERB', 'PRON', 'NUM' ...
# Dependency Labels: ['det', 'compound', 'nsubjpass', 'auxpass', 'ccomp', 'prep', 'det', 'pobj', 'prep', 'det', 'pobj', 'npadvmod', 'punct', 'nmod', 'punct', 'compound', 'nsubj', 'ccomp', 'prep', 'poss', 'pobj', 'advmod', 'prep', 'pcomp', 'advmod', 'nsubjpass', 'auxpass', 'advcl', 'prep', 'det', 'compound', 'pobj', 'prep', 'compound', 'pobj', 'punct', 'nsubjpass', 'aux', 'auxpass', 'ROOT', 'punct', 'det', 'nummod', 'punct', 'npadvmod', 'punct', 'nsubj', 'aux', 'aux', 'ROOT', 'prep', 'poss', 'pobj', 'advmod', 'nsubj', 'advcl', 'prep', 'pobj', 'prep', 'det', 'pobj', 'prep', 'det', 'compound', 'pobj', 'punct', 'det', 'nummod', 'punct', 'npadvmod', 'punct', 'amod', 'compound', 'compound', 'poss', 'case', 'nmod', 'nummod', 'compound', 'nsubjpass', 'auxpass', 'ROOT', 'prep', 'det', 'pobj', 'punct', 'prep', 'prep', 'det', 'pobj', 'punct', 'det', 'nsubj', 'ROOT', 'punct', 'advmod', 'acomp', 'punct', 'cc', 'conj', 'prep', 'det', 'pobj', 'prep', 'poss', 'case', 'compound', 'pobj', 'prep', 'advmod', 'pobj', 'prep', 'pobj', 'punct', 'poss', 'case', 'compound', 'punct', 'nsubj', 'ROOT', 'prt', 'det', 'compound', 'compound', 'compound', 'dobj', 'prep', 'det', 'pobj', 'punct', 'aux', 'advcl', 'det', 'dobj', 'intj', 'ROOT', 'dobj', 'punct', 'cc', 'conj', 'xcomp', 'prep', 'det', 'compound', 'pobj', 'nsubj', 'relcl', 'compound', 'dobj', 'nsubj', 'aux', 'advmod', 'ccomp', 'poss', 'case', 'compound', 'dobj', 'prep', 'pobj', 'prep', 'poss', 'pobj', 'advmod', 'prep', 'poss', 'pobj', 'case', 'nummod', 'punct', 'prep', 'compound', 'compound', 'pobj', 'prep', 'pobj', 'punct', 'det', 'nsubj', 'ROOT', 'det', 'dobj', 'punct', 'punct', 'det', 'nsubjpass', 'auxpass', 'advmod', 'ccomp', 'punct', 'punct', 'nsubj', 'advmod', 'ROOT', 'aux', 'advcl', 'mark', 'det', 'nsubj', 'ccomp', 'amod', 'cc', 'conj', 'attr', 'punct', 'punct', 'compound', 'compound', 'compound', 'nsubj', 'punct', 'appos', 'punct', 'ROOT', 'det', 'dobj', 'prep', 'det', 'pobj', 'prep', 'poss', 'amod', 'pobj', 'prep', 'pcomp', 'prep', 'det', 'pobj', 'prep', 'advmod', 'pobj', 'punct', 'nsubj', 'ROOT', 'punct', 'punct', 'expl', 'ccomp', 'attr', 'prep', 'pobj', 'acl', 'det', 'dobj', 'advcl', 'dobj', 'aux', 'xcomp', 'prt', 'mark', 'expl', 'advcl', 'attr', 'advmod', 'prep', 'det', 'pobj', 'punct', 'punct', 'nsubj', 'aux', 'ROOT', 'dobj', 'prep', 'compound', 'pobj', 'nsubj', 'aux', 'aux', 'relcl', 'prep', 'det', 'compound', 'pobj', 'punct', 'expl', 'ROOT', 'det', 'attr', 'prep', 'pobj', 'acl', 'punct', 'punct', 'nsubj', 'ccomp', 'punct', 'poss', 'case', 'ROOT', 'punct', 'punct', 'punct', 'nsubj', 'ROOT', 'poss', 'dobj', 'prep', 'pobj', 'prep', 'det', 'amod', 'pobj', 'ccomp', 'prt', 'cc', 'conj', 'prep', 'det', 'pobj', 'prep', 'det', 'pobj', 'mark', 'compound', 'nsubj', 'advcl', 'punct', 'det', 'nsubjpass', 'auxpass', 'ROOT', 'cc', 'nsubj', 'conj', 'neg', 'aux', 'xcomp', 'det', 'dobj', 'mark', 'det', 'amod', 'nsubj', 'advcl', 'nsubj', 'aux', 'neg', 'ccomp', 'aux', 'xcomp', 'prep', 'pobj', 'punct', 'nsubjpass', 'prep', 'det', 'pobj', 'auxpass', 'ROOT', 'advmod', 'punct', 'appos', 'punct', 'compound', 'nsubj', 'conj', 'prep', 'det', 'nummod', 'compound', 'pobj', 'prep', 'compound', 'pobj', 'prep', 'poss', 'case', 'compound', 'compound', 'pobj', 'punct', 'advmod', 'nsubj', 'aux', 'relcl', 'prep', 'pobj', 'advmod', 'prep', 'pobj', 'punct', 'det', 'nsubj', 'ROOT', 'det', 'dobj', 'punct', 'punct', 'det', 'nsubj', 'ccomp', 'prep', 'poss', 'pobj', 'advmod', 'prep', 'pcomp', 'poss', 'compound', 'punct', 'dobj', 'punct', 'nsubj', 'ROOT', 'det', 'amod', 'punct', 'amod', 'attr', 'cc', 'advmod', 'advmod', 'advmod', 'advmod', 'nsubj', 'advcl', 'dobj', 'punct', 'attr', 'nsubj', 'advcl', 'punct', 'punct', 'det', 'nsubj', 'ROOT', 'det', 'nsubj', 'aux', 'ccomp', 'prt', 'punct', 'nsubj', 'ROOT', 'advmod', 'punct', 'advmod', 'acomp', 'cc', 'conj', 'punct', 'nsubj', 'ROOT', 'neg', 'det', 'compound', 'attr', 'cc', 'aux', 'neg', 'conj', 'det', 'dobj', 'attr', 'compound', 'nsubj', 'relcl', 'punct', 'punct', 'compound', 'compou ...
#
#
# Text 3:
# Entities: ['Main NavigationSkip', 'United', '25 September 2023', 'United', 'the Carabao Cup', 'Crystal Palace', 'Tuesday 26 September', 'BST', 'Sky Sports', 'Erik', 'ten', 'Roy Hodgson', 'Eagles', "last season's", 'Newcastle United', 'Reds', 'February', "Eddie Howe's", '2017', 'Tuesday', 'the United App', '20', 'United', '20', 'United v Newcastle90', '20', 'Wembley', 'Erik', 'ten', 'Sky Sports', 'Tuesday', 'evening', 'the United App', 'Match Centre', 'MUTV', 'Match Day Live', '18:55 BST', 'Two-minute', 'midday', 'Wednesday', '90', '20', 'the day', 'WHATS', 'THE KEY TEAM NEWS', 'United', 'Lisandro Martinez', 'Harry Maguire', 'Mason Mount', '1', 'Burnley', 'Saturday', 'Raphael Varane', 'the second half', 'Sofyan Amrabat', 'Donny van de Beek', 'Sergio Reguilon', 'Ten', 'TNT Sports', 'Spaniard', 'Kobbie Mainoo', 'Carrington', 'last week', 'Mount', 'first', 'Luke Shaw', 'Tyrell Malacia', 'Amad', 'Jadon Sancho', 'Antony', 'Marc Guehi', '0', 'Fulham', 'Saturday', 'Michael Olise', 'James Tomkins', 'Jefferson Lerma', 'Matheus', '20', 'Burnley v United Video90', '20', 'Burnley v UnitedOur', 'Saturday', 'Clarets', 'Crystal Palace', 'Saturday 30 September', 'the Carabao Cup', 'Ten', "last year's", 'Reds', 'Palace', '63', '40', '2004', 'fourth', 'Louis Saha', 'Kieran Richardson', 'United', 'Ten', '2-1', 'Premier League', 'last season', 'Bruno Fernandes', 'Marcus Rashford', '20', 'United v Palace Video90', '20', 'PalaceWatch', 'Old Trafford', 'United', 'just one', '16', 'Tuesday', 'Wednesday', 'SEPTEMBERBradford City v', 'Peterborough Port Vale', 'Sutton Salford', 'Burnley UNITED', 'Crystal Palace', 'BST', '27', 'Brighton Fulham v', 'Norwich Lincoln', 'Liverpool', 'Leicester City Newcastle', '19:45', 'BST', 'the Match VideoWhy Bruno', 'MatchPlayer', 'Bruno', 'Burnley', 'Onana', 'VideoOnana', 'ClaretsPlayer', 'Andre Onana', 'Burnley', 'United', 'Monday 25', 'September 2023']
# TOKENS: ['Skip', 'to', 'Main', 'NavigationSkip', 'to', 'contentHow', 'to', 'follow', 'United', 'v', 'Crystal', 'PalaceMonday', '25', 'September', '2023', '09:00Manchester', 'United', 'will', 'begin', 'our', 'defence', 'of', 'the', 'Carabao', 'Cup', 'by', 'hosting', 'Crystal', 'Palace', 'at', 'Old', 'Trafford', 'on', 'Tuesday', '26', 'September', '.', 'The', '20:00', 'BST', 'kick', '-', 'off', ',', 'live', 'on', 'Sky', 'Sports', ',', 'will', 'see', 'Erik', 'ten', 'Hag', 'lock', 'horns', 'with', 'Roy', 'Hodgson', ',', 'with', 'the', 'Eagles', 'having', 'been', 'eliminated', 'from', 'last', 'season', "'s", 'competition', 'by', 'Newcastle', 'United', '.', 'The', 'Reds', 'met', 'the', 'Magpies', 'in', 'the', 'final', 'in', 'February', ',', 'defeating', 'Eddie', 'Howe', "'s", 'men', 'to', 'lift', 'our', 'first', 'piece', 'of', 'silverware', 'since', '2017', '.', 'Ahead', 'of', 'Tuesday', "'s", 'clash', ',', 'get', 'the', 'lowdown', 'on', 'how', 'both', 'sides', 'are', 'shaping', 'up', ',', 'the', 'key', 'team', 'news', 'and', 'how', 'you', 'can', 'follow', 'via', 'ManUtd.com', 'and', 'the', 'United', 'App', '...', '90', 'in', '20', ':', 'United', 'v', 'Newcastle', 'Video90', 'in', '20', ':', 'United', 'v', 'Newcastle90', 'in', '20', '|', 'Watch', 'the', 'extended', 'highlights', 'from', 'a', 'memorable', 'day', 'at', 'Wembley', 'for', 'Erik', 'ten', 'Hag', "'s", 'Reds', '...', 'HOW', 'CAN', 'YOU', 'FOLLOW', 'THE', 'ACTION', '?', 'The', 'match', 'is', 'being', 'shown', 'live', 'on', 'Sky', 'Sports', 'on', 'Tuesday', 'evening', ',', 'but', 'you', 'will', 'be', 'able', 'to', 'listen', 'to', 'live', 'commentary', 'in', 'the', 'United', 'App', '.', 'In', 'addition', ',', 'live', 'updates', ',', 'stats', 'and', 'images', 'will', 'be', 'regularly', 'posted', 'in', 'our', 'Match', 'Centre', '-', 'in', 'the', 'app', 'and', 'ManUtd.com', '-', 'throughout', '.', 'On', 'MUTV', ',', 'our', 'Match', 'Day', 'Live', 'show', 'commences', 'at', '18:55', 'BST', ',', 'with', 'bringing', 'you', 'exclusive', 'pre', '-', 'match', 'build', '-', 'up', 'and', 'post', '-', 'match', 'reaction', '.', 'Make', 'sure', 'you', 'tune', 'in', '!', 'WHERE', 'CAN', 'I', 'SEE', 'THE', 'HIGHLIGHTS', '?', 'Two', '-', 'minute', 'highlights', 'will', 'be', 'available', 'from', 'midday', 'on', 'Wednesday', ',', 'with', 'Full', '90', 'and', '90', 'in', '20', 'editions', 'also', 'set', 'to', 'follow', 'later', 'in', 'the', 'day', '.', 'WHATS', "'S", 'THE', 'KEY', 'TEAM', 'NEWS', '?', 'For', 'United', ',', 'Lisandro', 'Martinez', ',', 'Harry', 'Maguire', 'and', 'Mason', 'Mount', 'were', 'not', 'involved', 'in', 'our', '1', '-', '0', 'win', 'at', 'Burnley', 'on', 'Saturday', '.', 'However', ',', 'Raphael', 'Varane', 'came', 'off', 'the', 'bench', 'in', 'the', 'second', 'half', ',', 'along', 'with', 'new', 'signing', 'Sofyan', 'Amrabat', ',', 'who', 'made', 'his', 'debut', '.', 'Donny', 'van', 'de', 'Beek', 'was', 'also', 'among', 'the', 'substitutes', '.', 'Fellow', 'loan', 'arrival', 'Sergio', 'Reguilon', 'was', 'replaced', 'in', 'the', 'latter', 'stages', 'of', 'the', 'fixture', ',', 'with', 'Ten', 'Hag', 'confirming', 'afterwards', 'to', 'TNT', 'Sports', 'that', 'the', 'Spaniard', "'s", 'withdrawal', 'was', 'due', 'to', 'illness', ',', 'that', 'he', 'still', 'played', 'through', '.', 'Kobbie', 'Mainoo', 'was', 'seen', 'running', 'at', 'Carrington', 'last', 'week', ',', 'while', 'Mount', 'has', 'been', 'in', 'training', 'with', 'the', 'first', 'team', '.', 'Long', '-', 'term', 'absentees', 'Luke', 'Shaw', ',', 'Tyrell', 'Malacia', 'and', 'Amad', 'remain', 'out', ',', 'while', 'Jadon', 'Sancho', 'and', 'Antony', 'are', 'unavailable', '.', 'For', 'the', 'visitors', ',', 'Marc', 'Guehi', 'returned', 'for', 'the', 'Eagles', 'in', 'their', '0', '-', '0', 'draw', 'against', 'Fulham', 'on', 'Saturday', ',', 'while', 'they', 'remain', 'without', 'Michael', 'Olise', ',', 'James', 'Tomkins', ',', 'Jefferson', 'Lerma', 'and', 'Matheus', 'Franca.90', 'in', '20', ':', 'Burnley', 'v', 'Unit ...
# POS Tags: ['VERB', 'ADP', 'PROPN', 'PROPN', 'PART', 'VERB', 'PART', 'VERB', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'NUM', 'PROPN', 'NUM', 'NOUN', 'PROPN', 'AUX', 'VERB', 'PRON', 'NOUN', 'ADP', 'DET', 'PROPN', 'PROPN', 'ADP', 'VERB', 'PROPN', 'PROPN', 'ADP', 'PROPN', 'PROPN', 'ADP', 'PROPN', 'NUM', 'PROPN', 'PUNCT', 'DET', 'NUM', 'NOUN', 'VERB', 'PUNCT', 'NOUN', 'PUNCT', 'VERB', 'ADP', 'PROPN', 'PROPN', 'PUNCT', 'AUX', 'VERB', 'PROPN', 'NUM', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'PUNCT', 'ADP', 'DET', 'PROPN', 'AUX', 'AUX', 'VERB', 'ADP', 'ADJ', 'NOUN', 'PART', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'PUNCT', 'DET', 'PROPN', 'VERB', 'DET', 'PROPN', 'ADP', 'DET', 'ADJ', 'ADP', 'PROPN', 'PUNCT', 'VERB', 'PROPN', 'PROPN', 'PART', 'NOUN', 'PART', 'VERB', 'PRON', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'SCONJ', 'NUM', 'PUNCT', 'ADV', 'ADP', 'PROPN', 'PART', 'NOUN', 'PUNCT', 'VERB', 'DET', 'NOUN', 'ADP', 'SCONJ', 'DET', 'NOUN', 'AUX', 'VERB', 'ADP', 'PUNCT', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CCONJ', 'SCONJ', 'PRON', 'AUX', 'VERB', 'ADP', 'PROPN', 'CCONJ', 'DET', 'PROPN', 'PROPN', 'PUNCT', 'NUM', 'ADP', 'NUM', 'PUNCT', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'ADP', 'NUM', 'PUNCT', 'PROPN', 'PROPN', 'PROPN', 'ADP', 'NUM', 'NOUN', 'VERB', 'DET', 'VERB', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'PROPN', 'ADP', 'PROPN', 'NUM', 'PROPN', 'PART', 'PROPN', 'PUNCT', 'SCONJ', 'AUX', 'PRON', 'VERB', 'DET', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'AUX', 'AUX', 'VERB', 'ADV', 'ADP', 'PROPN', 'PROPN', 'ADP', 'PROPN', 'NOUN', 'PUNCT', 'CCONJ', 'PRON', 'AUX', 'AUX', 'ADJ', 'PART', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'DET', 'PROPN', 'PROPN', 'PUNCT', 'ADP', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'NOUN', 'CCONJ', 'NOUN', 'AUX', 'AUX', 'ADV', 'VERB', 'ADP', 'PRON', 'PROPN', 'PROPN', 'PUNCT', 'ADP', 'DET', 'NOUN', 'CCONJ', 'PROPN', 'PUNCT', 'NOUN', 'PUNCT', 'ADP', 'PROPN', 'PUNCT', 'PRON', 'PROPN', 'PROPN', 'ADJ', 'VERB', 'NOUN', 'ADP', 'NUM', 'PROPN', 'PUNCT', 'ADP', 'VERB', 'PRON', 'ADJ', 'ADJ', 'ADJ', 'ADJ', 'NOUN', 'PUNCT', 'NOUN', 'CCONJ', 'ADJ', 'ADJ', 'ADJ', 'NOUN', 'PUNCT', 'VERB', 'ADJ', 'PRON', 'VERB', 'ADP', 'PUNCT', 'SCONJ', 'AUX', 'PRON', 'VERB', 'DET', 'PROPN', 'PUNCT', 'NUM', 'PUNCT', 'NOUN', 'NOUN', 'AUX', 'AUX', 'ADJ', 'ADP', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'SCONJ', 'PROPN', 'NUM', 'CCONJ', 'NUM', 'ADP', 'NUM', 'NOUN', 'ADV', 'VERB', 'PART', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'PUNCT', 'PROPN', 'AUX', 'DET', 'PROPN', 'PROPN', 'PROPN', 'PUNCT', 'ADP', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'CCONJ', 'PROPN', 'PROPN', 'AUX', 'PART', 'VERB', 'ADP', 'PRON', 'NUM', 'SYM', 'NUM', 'NOUN', 'ADP', 'PROPN', 'ADP', 'PROPN', 'PUNCT', 'ADV', 'PUNCT', 'PROPN', 'PROPN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'ADP', 'ADP', 'ADJ', 'NOUN', 'PROPN', 'PROPN', 'PUNCT', 'PRON', 'VERB', 'PRON', 'NOUN', 'PUNCT', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'AUX', 'ADV', 'ADP', 'DET', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'NOUN', 'PROPN', 'PROPN', 'AUX', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT', 'ADP', 'NUM', 'PROPN', 'VERB', 'ADV', 'ADP', 'PROPN', 'PROPN', 'SCONJ', 'DET', 'PROPN', 'PART', 'NOUN', 'AUX', 'ADJ', 'ADP', 'NOUN', 'PUNCT', 'SCONJ', 'PRON', 'ADV', 'VERB', 'ADP', 'PUNCT', 'PROPN', 'PROPN', 'AUX', 'VERB', 'VERB', 'ADP', 'PROPN', 'ADJ', 'NOUN', 'PUNCT', 'SCONJ', 'PROPN', 'AUX', 'AUX', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'ADJ', 'PUNCT', 'NOUN', 'VERB', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'CCONJ', 'PROPN', 'VERB', 'ADP', 'PUNCT', 'SCONJ', 'PROPN', 'PROPN', 'CCONJ', 'PROPN', 'AUX', 'ADJ', 'PUNCT', 'ADP', 'DET', 'NOUN', 'PUNCT', 'PROPN', 'PROPN', 'VERB', 'ADP', 'DET', 'PROPN', 'ADP', 'PRON', 'NUM', 'SYM', 'NUM', 'NOUN', 'ADP', 'PROPN', 'ADP', 'PROPN', 'PUNCT', 'SCONJ', 'PRON', 'VERB', 'ADP', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'CCONJ', 'PROPN', 'VERB', 'ADP', 'NUM', 'PUNCT', 'PROPN', 'ADP', 'PROPN', 'PROPN', 'ADP', 'NUM', 'PUNCT', 'PROPN', 'NOUN', 'P ...
# Dependency Labels: ['advcl', 'prep', 'compound', 'pobj', 'aux', 'advcl', 'aux', 'advcl', 'compound', 'compound', 'dobj', 'nmod', 'nummod', 'nmod', 'nummod', 'compound', 'nsubj', 'aux', 'ROOT', 'poss', 'dobj', 'prep', 'det', 'compound', 'pobj', 'prep', 'pcomp', 'compound', 'dobj', 'prep', 'compound', 'pobj', 'prep', 'pobj', 'nummod', 'appos', 'punct', 'det', 'nummod', 'compound', 'nsubj', 'punct', 'prt', 'punct', 'advmod', 'prep', 'compound', 'pobj', 'punct', 'aux', 'ROOT', 'nmod', 'nummod', 'compound', 'compound', 'dobj', 'prep', 'compound', 'pobj', 'punct', 'prep', 'det', 'nsubjpass', 'aux', 'auxpass', 'pcomp', 'prep', 'amod', 'poss', 'case', 'pobj', 'prep', 'compound', 'pobj', 'punct', 'det', 'nsubj', 'ROOT', 'det', 'dobj', 'prep', 'det', 'pobj', 'prep', 'pobj', 'punct', 'advcl', 'compound', 'poss', 'case', 'dobj', 'aux', 'xcomp', 'poss', 'amod', 'dobj', 'prep', 'pobj', 'prep', 'pobj', 'punct', 'advmod', 'prep', 'poss', 'case', 'pobj', 'punct', 'ROOT', 'det', 'dobj', 'prep', 'advmod', 'det', 'nsubj', 'aux', 'pcomp', 'prt', 'punct', 'det', 'amod', 'compound', 'nsubj', 'cc', 'advmod', 'nsubj', 'aux', 'conj', 'prep', 'pobj', 'cc', 'det', 'compound', 'conj', 'punct', 'appos', 'prep', 'pobj', 'punct', 'compound', 'compound', 'appos', 'npadvmod', 'prep', 'pobj', 'punct', 'compound', 'compound', 'appos', 'prep', 'nummod', 'pobj', 'ccomp', 'det', 'amod', 'dobj', 'prep', 'det', 'amod', 'pobj', 'prep', 'pobj', 'prep', 'pobj', 'appos', 'poss', 'case', 'pobj', 'punct', 'advmod', 'aux', 'nsubj', 'ccomp', 'det', 'dobj', 'punct', 'det', 'nsubjpass', 'aux', 'auxpass', 'ROOT', 'advmod', 'prep', 'compound', 'pobj', 'prep', 'compound', 'pobj', 'punct', 'cc', 'nsubj', 'aux', 'conj', 'acomp', 'aux', 'xcomp', 'prep', 'amod', 'pobj', 'prep', 'det', 'compound', 'pobj', 'punct', 'prep', 'pobj', 'punct', 'amod', 'nsubjpass', 'punct', 'conj', 'cc', 'conj', 'aux', 'auxpass', 'advmod', 'ROOT', 'prep', 'poss', 'compound', 'pobj', 'punct', 'prep', 'det', 'pobj', 'cc', 'compound', 'punct', 'conj', 'punct', 'ROOT', 'pobj', 'punct', 'poss', 'compound', 'compound', 'nsubj', 'compound', 'pobj', 'prep', 'nummod', 'pobj', 'punct', 'prep', 'pcomp', 'dative', 'amod', 'amod', 'amod', 'amod', 'compound', 'punct', 'dobj', 'cc', 'amod', 'amod', 'amod', 'conj', 'punct', 'ROOT', 'acomp', 'nsubj', 'ccomp', 'prt', 'punct', 'advmod', 'aux', 'nsubj', 'ROOT', 'det', 'dobj', 'punct', 'nummod', 'punct', 'compound', 'nsubj', 'aux', 'ROOT', 'acomp', 'prep', 'pobj', 'prep', 'pobj', 'punct', 'mark', 'amod', 'nummod', 'cc', 'conj', 'quantmod', 'nummod', 'nsubj', 'advmod', 'advcl', 'aux', 'xcomp', 'advmod', 'prep', 'det', 'pobj', 'punct', 'nsubj', 'ROOT', 'det', 'compound', 'compound', 'attr', 'punct', 'prep', 'pobj', 'punct', 'compound', 'nsubjpass', 'punct', 'compound', 'conj', 'cc', 'compound', 'conj', 'auxpass', 'neg', 'ROOT', 'prep', 'poss', 'nummod', 'punct', 'prep', 'pobj', 'prep', 'pobj', 'prep', 'pobj', 'punct', 'advmod', 'punct', 'compound', 'nsubj', 'ROOT', 'prep', 'det', 'pobj', 'prep', 'det', 'amod', 'pobj', 'punct', 'prep', 'prep', 'amod', 'compound', 'compound', 'pobj', 'punct', 'nsubj', 'relcl', 'poss', 'dobj', 'punct', 'compound', 'compound', 'compound', 'nsubj', 'ROOT', 'advmod', 'prep', 'det', 'pobj', 'punct', 'amod', 'compound', 'nsubjpass', 'compound', 'appos', 'auxpass', 'ROOT', 'prep', 'det', 'amod', 'pobj', 'prep', 'det', 'pobj', 'punct', 'prep', 'nummod', 'nsubj', 'pcomp', 'advmod', 'prep', 'compound', 'pobj', 'mark', 'det', 'poss', 'case', 'nsubj', 'ccomp', 'acomp', 'prep', 'pobj', 'punct', 'mark', 'nsubj', 'advmod', 'advcl', 'prt', 'punct', 'compound', 'nsubjpass', 'auxpass', 'ROOT', 'xcomp', 'prep', 'pobj', 'amod', 'npadvmod', 'punct', 'mark', 'nsubj', 'aux', 'advcl', 'prep', 'pobj', 'prep', 'det', 'amod', 'pobj', 'punct', 'amod', 'punct', 'nsubj', 'nsubj', 'compound', 'appos', 'punct', 'compound', 'appos', 'cc', 'conj', 'ROOT', 'prt', 'punct', 'mark', 'compound', 'nsubj', 'cc', 'conj', 'advcl', 'acomp', 'punct', 'prep', 'det', 'pobj', 'punct', 'compound' ...
#
#
# Text 4:
# Entities: ['Manchester United', 'January', 'one', 'LaLiga', 'Erik', 'ten', 'Andre Onana', 'Old Trafford', 'third', 'this summer', 'Onana', 'Inter Milan', '43.8', 'Onana', '47.8', 'third', '27-year-old', 'Nerazzurri', 'just a year earlier', 'Inter’s', 'Onana', 'Old Trafford', '10', 'six', 'Burnley', 'Saturday', 'Cameroonian', 'Leroy Sane', 'Bayern Munich', 'Wednesday night', 'Onana', 'the weekend', 'Inter', 'Inter’s', 'Onana', 'United', 'David De Gea', 'Onana', 'United', 'January', 'summer', 'Man Utd', '50', 'Jan Oblak', 'Spain', 'United', 'Atletico Madrid', 'Jan Oblak', 'only 30', 'his 10th season', 'Atletico', 'Spain', 'one', 'United', 'Oblak', 'the years', '58', 'Slovenia', 'Spain', 'Atletico', 'just 98 days', 'Los Rojoblancos', '50', '43.6', 'United', 'Onana', 'the summer', 'Atletico', 'Onana', 'Diego Simeone’s', 'United', 'two', 'Dean Henderson', 'United', 'Oblak', 'Ten', 'Rasmus Hojlund', 'two', 'Hojlund', 'Dane']
# TOKENS: ['Manchester', 'United', 'are', 'reportedly', 'weighing', 'up', 'a', 'January', 'approach', 'for', 'one', 'of', 'LaLiga', '’s', 'best', 'goalkeepers', 'amid', 'claims', 'Erik', 'ten', 'Hag', 'already', 'has', 'doubts', 'over', 'big', 'summer', 'signing', 'Andre', 'Onana', 'at', 'Old', 'Trafford', '.', 'The', 'Red', 'Devils', 'forked', 'out', 'the', 'third', 'biggest', 'transfer', 'fee', 'for', 'a', 'goalkeeper', 'of', 'all', 'time', 'this', 'summer', 'to', 'bring', 'Onana', 'to', 'the', 'club', 'from', 'Inter', 'Milan', '.', 'Paying', 'an', 'initial', '£', '43.8', 'm', 'for', 'his', 'services', ',', 'the', 'final', 'fee', 'for', 'Onana', 'will', 'reach', '£', '47.8', 'm', 'once', 'add', '-', 'ons', 'are', 'factored', 'in', ',', 'putting', 'him', 'third', 'on', 'that', 'all', '-', 'time', 'list', '.', 'Astonishingly', ',', 'the', '27', '-', 'year', '-', 'old', 'had', 'joined', 'the', 'Nerazzurri', 'as', 'a', 'free', 'agent', 'just', 'a', 'year', 'earlier', ',', 'meaning', 'Inter', '’s', 'sale', 'earned', 'them', 'a', 'very', 'handsome', 'profit', 'on', 'their', 'original', 'investment', '.', 'However', ',', 'Onana', 'has', 'made', 'a', 'woeful', 'start', 'to', 'life', 'at', 'Old', 'Trafford', ',', 'conceding', 'an', 'alarming', '10', 'goals', 'from', 'their', 'six', 'games', 'to', 'date', '.', 'And', 'while', 'a', 'clean', 'sheet', 'at', 'Burnley', 'on', 'Saturday', 'will', 'have', 'gone', 'down', 'well', ',', 'the', 'Cameroonian', 'is', 'clearly', 'still', 'adapting', 'to', 'his', 'surroundings', 'having', 'conceded', 'plenty', 'of', 'all', '-', 'too', '-', 'soft', 'goals', ',', 'including', 'a', 'tame', 'effort', 'from', 'Leroy', 'Sane', 'in', 'their', 'loss', 'to', 'Bayern', 'Munich', 'on', 'Wednesday', 'night', '.', 'With', 'Onana', 'far', 'from', 'his', 'best', ',', 'reports', 'over', 'the', 'weekend', 'claim', 'Inter', 'felt', 'at', 'the', 'time', 'that', 'Inter', '’s', 'sale', 'of', 'Onana', 'for', 'such', 'a', 'high', 'fee', 'was', '‘', 'a', 'masterpiece', '’', 'with', 'United', 'mocked', 'for', 'paying', 'such', 'a', 'hefty', 'amount', 'for', 'a', 'player', 'who', 'it', 'is', 'felt', 'will', '‘', 'never', 'be', 'considered', 'world', 'class', '’', '.', 'With', 'several', 'pundits', 'also', 'claiming', 'the', 'decision', 'to', 'replace', 'long', '-', 'serving', 'David', 'De', 'Gea', 'with', 'Onana', 'was', 'the', 'wrong', 'one', ',', 'speculation', 'is', 'now', 'starting', 'to', 'mount', 'that', 'United', 'are', 'already', 'in', 'the', 'market', 'for', 'an', 'upgrade', 'when', 'the', 'January', 'window', 'opens', 'for', 'business', '.', 'READ', 'MORE:&nbsp;Ten', 'Hag', 'tipped', 'to', 'take', 'ruthless', 'action', 'on', 'key', 'position', 'as', 'pundit', 'questions', 'wisdom', 'of', 'huge', 'summer', 'decision', 'Man', 'Utd', 'tipped', 'to', 'make', '€', '50', 'm', 'move', 'for', 'Jan', 'Oblak', 'And', 'according', 'to', 'reports', 'in', 'Spain', ',', 'United', 'are', 'casting', 'their', 'eyes', 'towards', 'long', '-', 'standing', 'Atletico', 'Madrid', 'goalkeeper', 'Jan', 'Oblak', '.', 'Oblak', ',', 'still', 'only', '30', ',', 'is', 'now', 'into', 'his', '10th', 'season', 'as', 'an', 'Atletico', 'player', ',', 'having', 'established', 'himself', 'as', 'not', 'just', 'one', 'of', 'the', 'best', 'in', 'Spain', ',', 'but', 'also', 'one', 'of', 'the', 'world', '’s', 'elite', 'goalkeepers', '.', 'Indeed', ',', 'United', 'have', 'themselves', 'found', 'themselves', 'linked', 'with', 'a', 'move', 'for', 'Oblak', 'on', 'multiple', 'occasions', 'over', 'the', 'years', ',', 'despite', 'having', 'never', 'made', 'a', 'concrete', 'approach', 'for', 'the', '58', '-', 'times', 'capped', 'Slovenia', 'international', '.', 'Now', ',', 'however', ',', 'that', 'could', 'be', 'about', 'to', 'change', 'with', 'reports', 'in', 'Spain', 'claiming', 'Atletico', 'are', 'ready', 'to', 'put', 'Oblak', 'on', 'the', 'market', 'ahead', 'of', 'the', 'winter', 'window', 'opening', 'in', 'just', '98', 'days', '’', 'time', '.', 'And', 'per', 't ...
# ...
# Dependency Labels: ['compound', 'nsubj', 'aux', 'advmod', 'ROOT', 'prt', 'det', 'compound', 'dobj', 'prep', 'pobj', 'prep', 'poss', 'case', 'amod', 'pobj', 'prep', 'pobj', 'compound', 'compound', 'nsubj', 'advmod', 'relcl', 'dobj', 'prep', 'amod', 'compound', 'pobj', 'compound', 'dobj', 'prep', 'compound', 'pobj', 'punct', 'det', 'compound', 'nsubj', 'ROOT', 'prt', 'det', 'advmod', 'amod', 'compound', 'dobj', 'prep', 'det', 'pobj', 'prep', 'det', 'pobj', 'det', 'npadvmod', 'aux', 'advcl', 'dobj', 'prep', 'det', 'pobj', 'prep', 'compound', 'pobj', 'punct', 'advcl', 'det', 'amod', 'nmod', 'nummod', 'dobj', 'prep', 'poss', 'pobj', 'punct', 'det', 'amod', 'nsubj', 'prep', 'pobj', 'aux', 'ROOT', 'nmod', 'dobj', 'dobj', 'advmod', 'compound', 'punct', 'nsubjpass', 'auxpass', 'conj', 'prep', 'punct', 'advcl', 'dobj', 'advmod', 'prep', 'det', 'det', 'punct', 'compound', 'pobj', 'punct', 'advmod', 'punct', 'det', 'nummod', 'punct', 'npadvmod', 'punct', 'nsubj', 'aux', 'ROOT', 'det', 'dobj', 'prep', 'det', 'amod', 'pobj', 'advmod', 'det', 'npadvmod', 'advmod', 'punct', 'advcl', 'nmod', 'case', 'nsubj', 'ccomp', 'dative', 'det', 'advmod', 'amod', 'dobj', 'prep', 'poss', 'amod', 'pobj', 'punct', 'advmod', 'punct', 'nsubj', 'aux', 'ROOT', 'det', 'amod', 'dobj', 'prep', 'pobj', 'prep', 'compound', 'pobj', 'punct', 'advcl', 'det', 'amod', 'nummod', 'dobj', 'prep', 'poss', 'nummod', 'pobj', 'prep', 'pobj', 'punct', 'cc', 'mark', 'det', 'amod', 'nsubj', 'prep', 'pobj', 'prep', 'pobj', 'aux', 'aux', 'advcl', 'prt', 'advmod', 'punct', 'det', 'nsubj', 'aux', 'advmod', 'advmod', 'ROOT', 'prep', 'poss', 'pobj', 'aux', 'advcl', 'dobj', 'prep', 'advmod', 'punct', 'advmod', 'punct', 'amod', 'pobj', 'punct', 'prep', 'det', 'amod', 'pobj', 'prep', 'compound', 'pobj', 'prep', 'poss', 'pobj', 'prep', 'compound', 'pobj', 'prep', 'compound', 'pobj', 'punct', 'prep', 'pobj', 'advmod', 'prep', 'poss', 'pobj', 'punct', 'nsubjpass', 'prep', 'det', 'compound', 'pobj', 'nsubj', 'relcl', 'prep', 'det', 'pobj', 'advmod', 'poss', 'case', 'nsubj', 'prep', 'pobj', 'prep', 'predet', 'det', 'amod', 'pobj', 'relcl', 'punct', 'det', 'attr', 'punct', 'prep', 'pobj', 'acl', 'prep', 'pcomp', 'predet', 'det', 'amod', 'dobj', 'prep', 'det', 'pobj', 'dep', 'nsubjpass', 'auxpass', 'relcl', 'aux', 'punct', 'neg', 'auxpass', 'ROOT', 'compound', 'oprd', 'punct', 'punct', 'prep', 'amod', 'nsubj', 'advmod', 'pcomp', 'det', 'nsubj', 'aux', 'acl', 'advmod', 'punct', 'amod', 'compound', 'compound', 'dobj', 'prep', 'pobj', 'ccomp', 'det', 'amod', 'attr', 'punct', 'nsubj', 'aux', 'advmod', 'ROOT', 'aux', 'xcomp', 'mark', 'nsubj', 'ccomp', 'advmod', 'prep', 'det', 'pobj', 'prep', 'det', 'pobj', 'advmod', 'det', 'compound', 'nsubj', 'advcl', 'prep', 'pobj', 'punct', 'advcl', 'advmod', 'nsubj', 'ccomp', 'aux', 'xcomp', 'amod', 'dobj', 'prep', 'amod', 'pobj', 'prep', 'compound', 'compound', 'pobj', 'prep', 'amod', 'compound', 'pobj', 'compound', 'nsubj', 'ROOT', 'aux', 'xcomp', 'nmod', 'dobj', 'ccomp', 'ccomp', 'prep', 'compound', 'pobj', 'cc', 'prep', 'prep', 'pobj', 'prep', 'pobj', 'punct', 'nsubj', 'aux', 'conj', 'poss', 'dobj', 'prep', 'advmod', 'punct', 'amod', 'compound', 'compound', 'compound', 'compound', 'pobj', 'punct', 'nsubj', 'punct', 'advmod', 'advmod', 'appos', 'punct', 'ROOT', 'advmod', 'prep', 'poss', 'amod', 'pobj', 'prep', 'det', 'compound', 'pobj', 'punct', 'aux', 'advcl', 'dobj', 'prep', 'neg', 'advmod', 'pobj', 'prep', 'det', 'pobj', 'prep', 'pobj', 'punct', 'cc', 'advmod', 'conj', 'prep', 'det', 'poss', 'case', 'amod', 'pobj', 'punct', 'advmod', 'punct', 'nsubj', 'aux', 'nsubj', 'ROOT', 'nsubj', 'ccomp', 'prep', 'det', 'pobj', 'prep', 'pobj', 'prep', 'amod', 'pobj', 'prep', 'det', 'pobj', 'punct', 'prep', 'aux', 'neg', 'pcomp', 'det', 'amod', 'dobj', 'prep', 'det', 'nummod', 'punct', 'npadvmod', 'amod', 'compound', 'pobj', 'punct', 'advmod', 'punct', 'advmod', 'punct', 'nsubj', 'aux', 'ROOT', 'acomp', 'aux', 'xcomp', 'prep', 'pobj', 'prep', 'pobj', 'pcomp', 'nsubj', 'cco ...
#
#
# Text 5:
# Entities: ['Manchester City', 'Mateo Kovacic', 'Saturday', 'evening', 'Croatian', 'Kovacic', 'City', 'West Ham United', 'Red Star Belgrade', 'the Champions League', 'Nottingham Forest', 'Kovacic', '2', 'Nottingham Forest', 'Chelsea', 'Mateo Kovacic', 'Man City', 'Kovacic', 'Forest', 'Joe Prior', '£30 million', 'Newcastle United', 'the Carabao Cup', 'Wednesday night', 'BeanymanSports', 'Tomorrow', 'Sunday', 'Today', 'tomorrow', '”Guardiola’s', 'Saturday', 'evening', 'Sunday night', 'eight', 'Sunday', 'Kovacic', 'City', 'Kovacic', 'Kovacic', 'midweek', 'Newcastle', 'City', 'Rodri', 'three', 'Kalvin Phillips', 'Matt McNulty', 'England', 'Kovacic', '29-year-old', 'Wednesday']
# TOKENS: ['Pep', 'Guardiola', 'gave', 'an', 'injury', 'update', 'on', 'Manchester', 'City', 'midfielder', 'Mateo', 'Kovacic', 'on', 'Saturday', 'evening', '.', 'The', 'Croatian', 'has', 'been', 'on', 'the', 'sidelines', 'since', 'the', 'international', 'break', '.', 'Kovacic', 'picked', 'up', 'a', 'muscular', 'injury', 'while', 'on', 'duty', 'with', 'his', 'country', '.', 'So', 'far', ',', 'he', 'has', 'missed', 'City', '’s', 'games', 'against', 'West', 'Ham', 'United', ',', 'Red', 'Star', 'Belgrade', 'in', 'the', 'Champions', 'League', 'and', 'Nottingham', 'Forest', '.', 'But', 'it', 'looks', 'as', 'though', 'Kovacic', 'will', 'not', 'be', 'missing', 'for', 'much', 'longer', '.', 'After', 'the', '2', '-', '0', 'win', 'over', 'Nottingham', 'Forest', ',', 'Pep', 'delivered', 'an', 'update', 'on', 'the', 'former', 'Chelsea', 'man', '…', 'MORE', 'MAN', 'CITY', 'STORIES', 'Mateo', 'Kovacic', 'is', 'returning', 'soon', 'for', 'Man', 'City', 'after', 'picking', 'up', 'injury', 'on', 'international', 'dutyPep', 'was', 'asked', 'about', 'Kovacic', '’s', 'condition', 'after', 'the', 'game', 'with', 'Forest', '.', 'Photo', 'by', 'Joe', 'Prior', '/', 'Visionhaus', 'via', 'Getty', 'ImagesAnd', 'it', 'looks', 'as', 'though', 'he', 'the', '£', '30', 'million', 'man', 'is', 'going', 'to', 'be', 'in', 'contention', 'to', 'play', 'against', 'Newcastle', 'United', 'in', 'the', 'Carabao', 'Cup', 'on', 'Wednesday', 'night', '.', 'Pep', 'said', '(', 'BeanymanSports', '):', '“', 'Soon', '!', 'Tomorrow', '(', 'Sunday', ')', 'I', 'think', 'he', 'is', 'going', 'to', 'train', 'with', 'the', 'team', 'already', '.', 'Today', 'he', 'makes', 'a', 'partial', '(', 'recovery', ')', ',', 'but', 'we', 'did', 'n’t', 'take', 'a', 'risk', 'with', 'the', 'injury', 'that', 'he', 'had', 'in', 'the', 'leg', '.', 'This', 'place', 'is', 'riskier', 'than', 'in', 'other', 'places', '.', 'But', 'tomorrow', ',', 'he', 'starts', 'to', 'train', '.', '”Guardiola', '’s', 'comments', 'were', 'made', 'on', 'Saturday', 'evening', ',', 'but', 'embargoed', 'until', 'Sunday', 'night', '.', 'The', 'club', 'did', 'release', 'eight', 'new', 'training', 'photos', 'on', 'Sunday', ',', 'but', 'Kovacic', 'did', 'not', 'actually', 'appear', 'in', 'any', 'of', 'them', '.', 'So', 'it', 'is', 'unclear', 'if', 'he', 'did', 'train', ',', 'as', 'Pep', 'said', 'he', 'would', '.', 'Big', 'boost', 'for', 'City', 'that', 'Kovacic', '’s', 'return', 'is', 'imminentIt', 'sounds', 'very', 'much', 'as', 'though', 'Kovacic', 'will', 'be', 'available', 'for', 'the', 'midweek', 'clash', 'with', 'Newcastle', '.', 'That', '’s', 'a', 'big', 'boost', 'for', 'City', ',', 'especially', 'with', 'Rodri', 'now', 'being', 'suspended', 'for', 'three', 'games', '.', 'There', 'will', 'be', 'a', 'chance', 'for', 'Kalvin', 'Phillips', 'to', 'perhaps', 'stake', 'his', 'claim', 'to', 'play', '.', 'Photo', 'by', 'Matt', 'McNulty', '/', 'Getty', 'ImagesBut', 'we', 'have', 'seen', 'Pep', '’s', 'lack', 'of', 'faith', 'in', 'the', 'England', 'midfielder', 'and', 'it', '’s', 'very', 'possible', 'he', 'could', 'go', 'with', 'the', '‘', 'exceptional', '’', 'Kovacic', 'instead', '.', 'The', '29', '-', 'year', '-', 'old', 'has', 'enjoyed', 'a', 'terrific', 'start', 'at', 'City', 'and', 'many', 'fans', 'would', 'happily', 'see', 'him', 'back', 'in', 'the', 'team', 'on', 'Wednesday', '.', 'Related', 'Topics']
# POS Tags: ['PROPN', 'PROPN', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'NOUN', 'PROPN', 'PROPN', 'ADP', 'PROPN', 'NOUN', 'PUNCT', 'DET', 'PROPN', 'AUX', 'AUX', 'ADP', 'DET', 'NOUN', 'SCONJ', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'PROPN', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'SCONJ', 'ADP', 'NOUN', 'ADP', 'PRON', 'NOUN', 'PUNCT', 'ADV', 'ADV', 'PUNCT', 'PRON', 'AUX', 'VERB', 'PROPN', 'PART', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'PROPN', 'ADP', 'DET', 'PROPN', 'PROPN', 'CCONJ', 'PROPN', 'PROPN', 'PUNCT', 'CCONJ', 'PRON', 'VERB', 'SCONJ', 'SCONJ', 'PROPN', 'AUX', 'PART', 'AUX', 'VERB', 'ADP', 'ADV', 'ADJ', 'PUNCT', 'ADP', 'DET', 'NUM', 'SYM', 'NUM', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'PROPN', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'AUX', 'VERB', 'ADV', 'ADP', 'PROPN', 'PROPN', 'ADP', 'VERB', 'ADP', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'AUX', 'VERB', 'ADP', 'PROPN', 'PART', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'SYM', 'PROPN', 'ADP', 'PROPN', 'PROPN', 'PRON', 'VERB', 'SCONJ', 'SCONJ', 'PRON', 'DET', 'SYM', 'NUM', 'NUM', 'NOUN', 'AUX', 'VERB', 'PART', 'AUX', 'ADP', 'NOUN', 'PART', 'VERB', 'ADP', 'PROPN', 'PROPN', 'ADP', 'DET', 'PROPN', 'PROPN', 'ADP', 'PROPN', 'NOUN', 'PUNCT', 'PROPN', 'VERB', 'PUNCT', 'PROPN', 'PUNCT', 'PUNCT', 'ADV', 'PUNCT', 'NOUN', 'PUNCT', 'PROPN', 'PUNCT', 'PRON', 'VERB', 'PRON', 'AUX', 'VERB', 'PART', 'VERB', 'ADP', 'DET', 'NOUN', 'ADV', 'PUNCT', 'NOUN', 'PRON', 'VERB', 'DET', 'ADJ', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT', 'CCONJ', 'PRON', 'AUX', 'PART', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'SCONJ', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'AUX', 'ADJ', 'ADP', 'ADP', 'ADJ', 'NOUN', 'PUNCT', 'CCONJ', 'NOUN', 'PUNCT', 'PRON', 'VERB', 'PART', 'VERB', 'PUNCT', 'PROPN', 'PART', 'NOUN', 'AUX', 'VERB', 'ADP', 'PROPN', 'NOUN', 'PUNCT', 'CCONJ', 'VERB', 'ADP', 'PROPN', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'AUX', 'VERB', 'NUM', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'CCONJ', 'PROPN', 'AUX', 'PART', 'ADV', 'VERB', 'ADP', 'PRON', 'ADP', 'PRON', 'PUNCT', 'ADV', 'PRON', 'AUX', 'ADJ', 'SCONJ', 'PRON', 'VERB', 'VERB', 'PUNCT', 'SCONJ', 'PROPN', 'VERB', 'PRON', 'AUX', 'PUNCT', 'ADJ', 'NOUN', 'ADP', 'PROPN', 'PRON', 'PROPN', 'PART', 'NOUN', 'AUX', 'PRON', 'VERB', 'ADV', 'ADV', 'SCONJ', 'SCONJ', 'PROPN', 'AUX', 'AUX', 'ADJ', 'ADP', 'DET', 'ADJ', 'VERB', 'ADP', 'PROPN', 'PUNCT', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'ADV', 'ADP', 'PROPN', 'ADV', 'AUX', 'VERB', 'ADP', 'NUM', 'NOUN', 'PUNCT', 'PRON', 'AUX', 'AUX', 'DET', 'NOUN', 'SCONJ', 'PROPN', 'PROPN', 'PART', 'ADV', 'VERB', 'PRON', 'NOUN', 'PART', 'VERB', 'PUNCT', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'SYM', 'PROPN', 'PROPN', 'PRON', 'AUX', 'VERB', 'PROPN', 'PART', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'PROPN', 'NOUN', 'CCONJ', 'PRON', 'VERB', 'ADV', 'ADJ', 'PRON', 'AUX', 'VERB', 'ADP', 'DET', 'PUNCT', 'ADJ', 'PUNCT', 'VERB', 'ADV', 'PUNCT', 'DET', 'NUM', 'PUNCT', 'NOUN', 'PUNCT', 'ADJ', 'AUX', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'PROPN', 'CCONJ', 'ADJ', 'NOUN', 'AUX', 'ADV', 'VERB', 'PRON', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'ADJ', 'NOUN']
# Dependency Labels: ['compound', 'nsubj', 'ROOT', 'det', 'compound', 'dobj', 'prep', 'compound', 'compound', 'compound', 'compound', 'pobj', 'prep', 'compound', 'pobj', 'punct', 'det', 'nsubj', 'aux', 'ROOT', 'prep', 'det', 'pobj', 'prep', 'det', 'amod', 'pobj', 'punct', 'nsubj', 'ROOT', 'prt', 'det', 'amod', 'dobj', 'mark', 'advcl', 'pobj', 'prep', 'poss', 'pobj', 'punct', 'advmod', 'advmod', 'punct', 'nsubj', 'aux', 'ROOT', 'poss', 'case', 'dobj', 'prep', 'compound', 'compound', 'pobj', 'punct', 'compound', 'compound', 'appos', 'prep', 'det', 'compound', 'pobj', 'cc', 'compound', 'conj', 'punct', 'cc', 'nsubj', 'ROOT', 'mark', 'mark', 'nsubj', 'aux', 'neg', 'aux', 'advcl', 'prep', 'advmod', 'pcomp', 'punct', 'prep', 'det', 'nummod', 'punct', 'prep', 'pobj', 'prep', 'compound', 'pobj', 'punct', 'nsubj', 'advcl', 'det', 'dobj', 'prep', 'det', 'amod', 'compound', 'pobj', 'punct', 'amod', 'compound', 'compound', 'compound', 'compound', 'nsubj', 'aux', 'ROOT', 'advmod', 'prep', 'compound', 'pobj', 'prep', 'pcomp', 'prt', 'dobj', 'prep', 'pobj', 'cc', 'auxpass', 'conj', 'prep', 'poss', 'case', 'pobj', 'prep', 'det', 'pobj', 'prep', 'pobj', 'punct', 'ROOT', 'prep', 'nmod', 'nmod', 'punct', 'pobj', 'prep', 'punct', 'dep', 'nsubj', 'ROOT', 'mark', 'mark', 'nsubj', 'det', 'quantmod', 'compound', 'nummod', 'nsubj', 'aux', 'advcl', 'aux', 'xcomp', 'prep', 'pobj', 'aux', 'advcl', 'prep', 'compound', 'pobj', 'prep', 'det', 'compound', 'pobj', 'prep', 'compound', 'pobj', 'punct', 'nsubj', 'ROOT', 'punct', 'appos', 'punct', 'punct', 'advmod', 'punct', 'npadvmod', 'punct', 'appos', 'punct', 'nsubj', 'ROOT', 'nsubj', 'aux', 'ccomp', 'aux', 'xcomp', 'prep', 'det', 'pobj', 'advmod', 'punct', 'npadvmod', 'nsubj', 'ROOT', 'det', 'amod', 'punct', 'dobj', 'punct', 'punct', 'cc', 'nsubj', 'aux', 'neg', 'conj', 'det', 'dobj', 'prep', 'det', 'pobj', 'dobj', 'nsubj', 'relcl', 'prep', 'det', 'pobj', 'punct', 'det', 'nsubj', 'ROOT', 'acomp', 'prep', 'prep', 'amod', 'pobj', 'punct', 'cc', 'npadvmod', 'punct', 'nsubj', 'ROOT', 'aux', 'xcomp', 'punct', 'poss', 'case', 'nsubjpass', 'auxpass', 'ROOT', 'prep', 'compound', 'pobj', 'punct', 'cc', 'conj', 'prep', 'compound', 'pobj', 'punct', 'det', 'nsubj', 'aux', 'ROOT', 'nummod', 'amod', 'compound', 'dobj', 'prep', 'pobj', 'punct', 'cc', 'nsubj', 'aux', 'neg', 'advmod', 'conj', 'prep', 'pobj', 'prep', 'pobj', 'punct', 'advmod', 'nsubj', 'ROOT', 'acomp', 'mark', 'nsubj', 'advcl', 'dobj', 'punct', 'mark', 'nsubj', 'advcl', 'nsubj', 'ccomp', 'punct', 'amod', 'nsubj', 'prep', 'pobj', 'mark', 'poss', 'case', 'nsubj', 'relcl', 'attr', 'ROOT', 'advmod', 'advmod', 'mark', 'mark', 'nsubj', 'aux', 'advcl', 'acomp', 'prep', 'det', 'amod', 'pobj', 'prep', 'pobj', 'punct', 'nsubj', 'ROOT', 'det', 'amod', 'nsubjpass', 'prep', 'pobj', 'punct', 'advmod', 'prep', 'pobj', 'advmod', 'auxpass', 'ccomp', 'prep', 'nummod', 'pobj', 'punct', 'expl', 'aux', 'ROOT', 'det', 'attr', 'mark', 'compound', 'nsubj', 'aux', 'advmod', 'acl', 'poss', 'dobj', 'aux', 'acl', 'punct', 'npadvmod', 'prep', 'nmod', 'nmod', 'punct', 'compound', 'pobj', 'nsubj', 'aux', 'ROOT', 'poss', 'case', 'dobj', 'prep', 'pobj', 'prep', 'det', 'compound', 'pobj', 'cc', 'nsubj', 'conj', 'advmod', 'acomp', 'nsubj', 'aux', 'ccomp', 'prep', 'det', 'punct', 'amod', 'punct', 'pobj', 'advmod', 'punct', 'det', 'nummod', 'punct', 'npadvmod', 'punct', 'nsubj', 'aux', 'ROOT', 'det', 'amod', 'dobj', 'prep', 'pobj', 'cc', 'amod', 'nsubj', 'aux', 'advmod', 'conj', 'dobj', 'advmod', 'prep', 'det', 'pobj', 'prep', 'pobj', 'punct', 'amod', 'ROOT']

# %%
# Process each entry with spaCy and extract names (PERSON) and clubs (ORG)
for i, content in enumerate(top_five_content):
    doc = nlp(content)
    names = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
    clubs = [ent.text for ent in doc.ents if ent.label_ == "ORG"]
    print(f"Text {i + 1}:")
    print(f"Names: {names}")
    print(f"Clubs: {clubs}")
    print("\n")
# Out:
# Text 1:
# Names: ['Alisson', 'Alisson', 'Ederson', 'Arijanet Muric - Burnley', 'James Trafford', 'Aijanet Muric', 'Emiliano Martinez - Aston', 'Emiliano Martinez', 'Bernd Leno', 'Aston Villa', 'Martinez', 'David Raya - Arsenal', 'David Raya', 'David Raya', 'Aaron Ramsdale', 'Raya', 'Jordan Pickford - Everton', 'Gareth Southgate', 'Jordan Pickford', 'Odysseas Vlachodimos', 'Matt Turner', 'Robert Sanchez - Chelsea', 'Robert Sanchez', 'Robin Jones - AFC Bournemouth', 'Brighton', 'Jason Steele', 'Robert Sanchez', 'Edouard Mendy', 'Kepa Arrizabalaga', 'Andre Onana - Man Utd', "David de Gea's", 'Alisson', 'Alisson', 'Jurgen Klopp', 'Claudio Bravo', 'Aaron Ramsdale - Arsenal', "Mikel Arteta's", 'Raya', 'Aaron Ramsdale', 'Gunners', 'Raya', 'Virgin Media']
# Clubs: ['Premier League', 'Ederson and AlissonLiverpool', 'Ederson', 'The Football Observatory', 'Mirror Football', 'Burnley', 'Getty Images', 'Brentford', 'Everton', 'Everton', 'Vlachodimos - Nottingham Forest', 'Nottingham Forest', 'Forest', 'Chelsea', 'Getty Images', 'Chelsea', 'Inter Milan', 'Cameroon', 'Inter', 'the Champions League', 'Old Trafford', 'Alisson - Liverpool', 'Ederson ( Image:', 'Reds', 'the Premier League', 'Champions League', 'FA Cup', 'Ederson - Man City', 'Ederson', 'Ederson', 'Premier League', 'League Cups', 'The Football Observatory', 'The Football Observatory', 'WhatsApp', 'Mirror Football', 'Champions League', 'TNT Sports', 'the Premier League', 'Champions League', 'Serie A', 'UFC', 'WWE', 'MLB', 'TNT Sports', 'Sky', 'TNT Sports']
#
#
# Text 2:
# Names: ['Marcus Rashford', 'Rashford', 'HTML5', 'Maintenance', 'Peter Laycock', 'Peter', 'Rashford', 'Carrington Spur', 'Marcus Rashford', 'Bruno Fernandes', 'Rashford', 'Rashford', 'reCAPTCHA']
# Clubs: ['Manchester United', 'Sun', 'United', 'Rolls-Royce', 'United', 'Burnley', 'Sun', 'United', 'United', 'United', 'the Google Privacy Policy and Terms of Service']
#
#
# Text 3:
# Names: ['Main NavigationSkip', 'Erik', 'Roy Hodgson', 'Erik', 'Lisandro Martinez', 'Harry Maguire', 'Raphael Varane', 'Sofyan Amrabat', 'Donny van de Beek', 'Sergio Reguilon', 'Kobbie Mainoo', 'Luke Shaw', 'Tyrell Malacia', 'Amad', 'Jadon Sancho', 'Marc Guehi', 'Michael Olise', 'James Tomkins', 'Jefferson Lerma', 'Matheus', 'Burnley v United Video90', 'Burnley v UnitedOur', 'Louis Saha', 'Kieran Richardson', 'Marcus Rashford', 'PalaceWatch', 'Sutton Salford', 'Burnley UNITED', 'Brighton Fulham v', 'Norwich Lincoln', 'Bruno', 'VideoOnana', 'ClaretsPlayer', 'Andre Onana']
# Clubs: ['United', 'United', 'BST', 'Sky Sports', 'Newcastle United', 'Reds', "Eddie Howe's", 'United', 'United v Newcastle90', 'Sky Sports', 'MUTV', 'WHATS', 'THE KEY TEAM NEWS', 'United', 'Burnley', 'TNT Sports', 'Antony', 'Fulham', 'Clarets', 'Reds', 'Palace', 'United', 'Premier League', 'Bruno Fernandes', 'United v Palace Video90', 'Old Trafford', 'United', 'BST', 'Leicester City Newcastle', 'BST', 'the Match VideoWhy Bruno', 'MatchPlayer', 'Burnley', 'Burnley', 'United']
#
#
# Text 4:
# Names: ['Erik', 'Nerazzurri', 'David De Gea', 'Man Utd', 'Jan Oblak', 'Jan Oblak', 'Atletico', 'Oblak', 'Atletico', 'Diego Simeone’s', 'Dean Henderson', 'Oblak', 'Rasmus Hojlund', 'Dane']
# Clubs: ['Manchester United', 'LaLiga', 'Old Trafford', 'Inter Milan', 'Inter’s', 'Old Trafford', 'Burnley', 'Bayern Munich', 'Inter’s', 'United', 'United', 'United', 'Atletico Madrid', 'United', 'Los Rojoblancos', 'United', 'United', 'United']
#
#
# Text 5:
# Names: ['Mateo Kovacic', 'Kovacic', 'Kovacic', 'Mateo Kovacic', 'Kovacic', 'Joe Prior', 'BeanymanSports', 'Kovacic', 'Kovacic', 'Kovacic', 'Kalvin Phillips', 'Matt McNulty', 'Kovacic']
# Clubs: ['City', 'Red Star Belgrade', 'the Champions League', 'Nottingham Forest', 'Nottingham Forest', 'Chelsea', 'Forest', 'Newcastle United', '”Guardiola’s']

# %%
first_content = df['content'].iloc[0]

# Process the first entry with spaCy
doc = nlp(first_content)

# Extract names (PERSON) and clubs (ORG)
names = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
clubs = [ent.text for ent in doc.ents if ent.label_ == "ORG"]

# Display the content and extracted entities
print("Content of the first entry:")
print(first_content)
print("\nExtracted names:")
print(names)
print("\nExtracted clubs:")
print(clubs)
# Out:
# Content of the first entry:
# The top 10 most valuable Premier League goalkeepers have been revealed, with Liverpool's Alisson and Manchester City's Ederson missing out on the number one spotManchester City and Liverpool goalkeepers Ederson and AlissonLiverpool star Alisson and Manchester City's Ederson are widely viewed as two of the best goalkeepers in the world - but where do they rank among the Premier League's most valuable shot-stoppers? Well, The Football Observatory has all the answers and you might be surprised to learn that neither Alisson or Ederson take the number one spot. When ranking players' value, they take a wide range of factors into account: age, contract length, form and so on. A total of nine different clubs are represented in the top 10, with Arsenal the only club having two players on the list. Here, Mirror Football gives you the rundown on the league's most valuable goalkeepers... 10. Arijanet Muric - Burnley (€20million/£17.3m) After losing his spot as Burnley's first-choice goalkeeper to new signing James Trafford, Aijanet Muric is probably the most surprising name on the list. However, the 24-year-old was excellent in the Championship last year, while his age and the fact he is under contract until 2026 help boost his value. 9. Emiliano Martinez - Aston Villa (€20m/£17.3m) A World Cup winner with Argentina last year, Emiliano Martinez has developed into one of the best goalkeepers in the world after enjoying a breakthrough at Arsenal in 2020 when Bernd Leno was sidelined with an injury. After joining Aston Villa later that same year, Martinez has continued to impress and the 31-year-old signed a three-year contract extension last January. 8. David Raya - Arsenal (€20m/£17.3m) David Raya joined Arsenal over the summer ( Image: Arsenal FC via Getty Images) Currently on loan at Arsenal from Brentford with an option for the deal to be made permanent next summer, David Raya is now competing with Aaron Ramsdale for the No 1 spot at the Emirates. Spanish international Raya did sign a two-year contract extension with Brentford before joining the Gunners in case they do not take up the option to buy. 7. Jordan Pickford - Everton (€20m/£17.3m) England's first-choice goalkeeper under Gareth Southgate, Jordan Pickford made the move to Everton in 2017 after impressing as Sunderland were relegated to the Championship. The 29-year-old has come in for criticism over the years, but he remains one of Everton's key players after committing his future to the club until the end of 2027 earlier this year. 6. Odysseas Vlachodimos - Nottingham Forest (€30m/£26m) Another surprising name on the list, Odysseas Vlachodimos joined Nottingham Forest from Benfica over the summer on a four-year deal. However, the 29-year-old is yet to play a game for Forest with Matt Turner their new first-choice following his move from Arsenal. 5. Robert Sanchez - Chelsea (€30m/£26m) Robert Sanchez is Chelsea's new No 1 ( Image: Robin Jones - AFC Bournemouth/AFC Bournemouth via Getty Images) After losing his place in Brighton's team to Jason Steele last season, Robert Sanchez made a £20m move to Chelsea this summer and became their new No 1 after the departures of Edouard Mendy and Kepa Arrizabalaga. The 25-year-old signed a seven-year contract with the Blues and has started every game since joining the club. 4. Andre Onana - Man Utd (€50m/£43.4m) Another new signing, Manchester United forked out an initial £43.8m to sign Andre Onana from Inter Milan as David de Gea's replacement. The Cameroon international played a key role in Inter's run to the Champions League final last season, but has not enjoyed the greatest start to life at Old Trafford. 3. Alisson - Liverpool (€60m/£52.1m) Alisson is valued the same as Ederson ( Image: Getty Images) Since making the move from Roma to Liverpool in 2018, Alisson has played an integral role in the Reds' success under Jurgen Klopp. The 30-year-old, who is under contract until 2027, has helped Liverpool lift the Premier League, Champions L ...
#
# Extracted names:
# ['Alisson', 'Alisson', 'Ederson', 'Arijanet Muric - Burnley', 'James Trafford', 'Aijanet Muric', 'Emiliano Martinez - Aston', 'Emiliano Martinez', 'Bernd Leno', 'Aston Villa', 'Martinez', 'David Raya - Arsenal', 'David Raya', 'David Raya', 'Aaron Ramsdale', 'Raya', 'Jordan Pickford - Everton', 'Gareth Southgate', 'Jordan Pickford', 'Odysseas Vlachodimos', 'Matt Turner', 'Robert Sanchez - Chelsea', 'Robert Sanchez', 'Robin Jones - AFC Bournemouth', 'Brighton', 'Jason Steele', 'Robert Sanchez', 'Edouard Mendy', 'Kepa Arrizabalaga', 'Andre Onana - Man Utd', "David de Gea's", 'Alisson', 'Alisson', 'Jurgen Klopp', 'Claudio Bravo', 'Aaron Ramsdale - Arsenal', "Mikel Arteta's", 'Raya', 'Aaron Ramsdale', 'Gunners', 'Raya', 'Virgin Media']
#
# Extracted clubs:
# ['Premier League', 'Ederson and AlissonLiverpool', 'Ederson', 'The Football Observatory', 'Mirror Football', 'Burnley', 'Getty Images', 'Brentford', 'Everton', 'Everton', 'Vlachodimos - Nottingham Forest', 'Nottingham Forest', 'Forest', 'Chelsea', 'Getty Images', 'Chelsea', 'Inter Milan', 'Cameroon', 'Inter', 'the Champions League', 'Old Trafford', 'Alisson - Liverpool', 'Ederson ( Image:', 'Reds', 'the Premier League', 'Champions League', 'FA Cup', 'Ederson - Man City', 'Ederson', 'Ederson', 'Premier League', 'League Cups', 'The Football Observatory', 'The Football Observatory', 'WhatsApp', 'Mirror Football', 'Champions League', 'TNT Sports', 'the Premier League', 'Champions League', 'Serie A', 'UFC', 'WWE', 'MLB', 'TNT Sports', 'Sky', 'TNT Sports']

# %%
num_chunks = 5
chunk_size = len(df) // num_chunks

# Save each chunk to a separate CSV file
for i in range(num_chunks):
    start_idx = i * chunk_size
    end_idx = (i + 1) * chunk_size if i < num_chunks - 1 else len(df)

    # Extract the chunk
    chunk = df.iloc[start_idx:end_idx]

    # Save the chunk to a CSV file
    chunk.to_csv(f"/content/drive/MyDrive/nlp data/Data/news_feed_chunk_{i + 1}.csv", index=False)
    print(f"Chunk {i + 1} saved.")
# Out:
# Chunk 1 saved.
# Chunk 2 saved.
# Chunk 3 saved.
# Chunk 4 saved.
# Chunk 5 saved.

# %%
from tqdm import tqdm

def extract_names(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ == "PERSON"]

def extract_clubs(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ == "ORG"]

def extract_fee(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ == "MONEY"]

# Initialize tqdm for progress monitoring
tqdm.pandas(desc="Processing content")

# Load the first chunk
chunk_number = 1
chunk = pd.read_csv(f"/content/drive/MyDrive/nlp data/Data/news_feed_chunk_{chunk_number}.csv")

# Apply the functions to the 'content' column with progress monitoring
chunk['names'] = chunk['content'].progress_apply(lambda x: ', '.join(extract_names(x)))
chunk['clubs'] = chunk['content'].progress_apply(lambda x: ', '.join(extract_clubs(x)))
chunk['fee'] = chunk['content'].progress_apply(lambda x: ', '.join(extract_fee(x)))

# Save the processed chunk to a new CSV file
chunk.to_csv(f"/content/drive/MyDrive/nlp data/Data/news_feed_chunk_{chunk_number}_processed.csv", index=False)

# Display the updated DataFrame with new columns
chunk[['content', 'names', 'clubs', 'fee']].head()
# Out:
# Processing content:  99%|█████████▉| 26841/27001 [42:31<00:20,  7.99it/s]
